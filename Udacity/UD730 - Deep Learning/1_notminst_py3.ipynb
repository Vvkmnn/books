# %% [markdown]
# Deep Learning
# =============
#
# Assignment 1
# ------------
#
# The objective of this assignment is to learn about simple data curation practices, and familiarize you with some of the data we'll be reusing later.
#
# This notebook uses the [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) dataset to be used with python experiments. This dataset is designed to look like the classic [MNIST](http://yann.lecun.com/exdb/mnist/) dataset, while looking a little more like real data: **it's a harder task, and the data is a lot less 'clean' than MNIST.**

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

# General variables
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
import pickle

# iPython Packages
from IPython.display import display, Image

# ML Packages
from scipy import ndimage
from sklearn.linear_model import LogisticRegression

# Download Packages
from urllib.request import urlretrieve

# Configuration
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %% [markdown]
# First, we'll download the dataset to our local machine. The data consists of characters rendered in a variety of fonts on a 28x28 image. The labels are limited to 'A' through 'J' (10 classes). The training set has about 500k and the testset 19000 labelled examples. Given these sizes, it should be possible to train models quickly on any machine.

# %%
# Seed the numpy randomizer early on so we always get 
# our 'random' values back
np.random.seed(42)

# %%
# What directory are you working from? Let's remember that
maindir = os.getcwd()
print(maindir)
# Out:
# /Users/vivek.menon/Dropbox/learn/books/Udacity/UD730 - Deep Learning

# %%
# Some folder walking tools

def root_folder():
    os.chdir(maindir)
    
def current_folder():
    print('Current folder: {}'.format(os.getcwd().split('/')[-1]))
    return os.getcwd()
    
def data_folder():
    root_folder()
    
    if not os.path.exists('data'):
    # Make a 'data' folder to hold these datasets if doesn't exist yet
        print('Creating data folder')
        os.makedirs('data')
    else:
        os.chdir('data')
    
    

current_folder()
data_folder()
current_folder()
root_folder()
# Out:
# Current folder: UD730 - Deep Learning
# Current folder: data

# %%
url = 'http://commondatastorage.googleapis.com/books1000/'
# Where are we going? 

last_percent_reported = None
# Assume we've not downloaded anything

def download_progress_hook(count, blockSize, totalSize):
    """A hook to report the progress of a download. This is mostly intended for users with
    slow internet connections. Reports every 1% change in download progress.
    """
    global last_percent_reported
    # Reference the global percent variable
    
    percent = int(count * blockSize * 100 / totalSize)
    # Take the count * blockSize / totalSize , multiply by 100 for a percent

    if last_percent_reported != percent:
    # If the precent has since changed
        if percent % 5 == 0:
            # And if the current precent is past an increment of 5
            sys.stdout.write("%s%%" % percent)
            # Print the current percent at 5% increments
            sys.stdout.flush()
            # Flsuh the terminal; doesn't seem to do anything in Jupyter
        else:
            sys.stdout.write(".")
            # Else just print a '.'
            sys.stdout.flush()
            
    last_percent_reported = percent
    # Set the last_percent_reported global to the current percent given
        
def download(filename, expected_bytes, force=False):
    """Download a file if not present, and make sure it's the right size."""
    
        
    if force or not os.path.exists(filename):      
    # If force == True or the data does not exist  
        print('Attempting to download:', filename) 
        download = urlretrieve(url + filename, filename, reporthook=download_progress_hook)
        # Download the filename, and use the download_progress_hook inteface to report back results 
        # reporthook probably hands off count, blockSize, totalSize, and other info, because its not in here
        # urlretreive returns a tuple: ('filename', <httplib.HTTPMessage instance at someaddress>) 
        # Use filename, _ to split the name from the other stuff (we use _ to store the misc stuff) 
        
        filename, _ = download
        #print('Retrieved tuple named {}, so split it into {} and {}'.format(download, filename, _))

        # Confirm completion
        print('\nDownload Complete!')
        
    statinfo = os.stat(filename)
    # Check the bytesize of our new file
    
    if statinfo.st_size == expected_bytes:
    # If the filesize matches expected bytes
        print('Found and verified', filename)
    else:
    # If it's not 
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
        # Raise an exception to tell me it didn't work
    
    return filename
    # Returns the actual name when called, but will do this whole function in an attempt to return this

    
data_folder()
# Jump into the data folder 

train_filename = download('notMNIST_large.tar.gz', 247336696)
# What is the training file

test_filename = download('notMNIST_small.tar.gz', 8458043)
# What is the testing file
# Out:
# Found and verified notMNIST_large.tar.gz
# Found and verified notMNIST_small.tar.gz

# %% [markdown]
# Extract the dataset from the compressed .tar.gz file.
# This should give you a set of directories, labelled A through J.

# %%
def extract(filename, num_classes, force=False):
    """Extract the .tar into subfolders, and check if right number of classes."""
    
    root = os.path.splitext(os.path.splitext(filename)[0])[0]  
    # remove the file type at the '.'; first for .gz, then for .tar

    if os.path.isdir(root) and not force:
        # You may override by setting force=True.
        print('%s already present - Skipping extraction of %s.' % (root, filename))
        # The directory already exists
    else:
        print('Extracting data for %s. This may take a while. Please wait.' % root)
        tar = tarfile.open(filename)
        # open the file as a 
        sys.stdout.flush()
        # Clean the terminal output
        tar.extractall()
        # Extract the tar file into the directory
        tar.close()
        # Close the tar
    
    data_folders = [os.path.join(root, d) for d in sorted(os.listdir(root)) if os.path.isdir(os.path.join(root, d))]
    # List comprehension to get all subfolder strings from a list of all folders if they are each directories
    
    if len(data_folders) != num_classes:
    # if there are few folders than expected, raise exception
        raise Exception('Expected %d folders, one per class. Found %d instead.' % (num_classes, len(data_folders)))
    print(data_folders)
    # Say what they are
    
    return data_folders
    # return it for convenience 

data_folder()
# Jump into the data folder 

train_folders = extract(train_filename, 10)
# What are the training folders (I expect 10)

test_folders = extract(test_filename, 10)
# What are the test folders (I expect 10)
# Out:
# notMNIST_large already present - Skipping extraction of notMNIST_large.tar.gz.
# ['notMNIST_large/A', 'notMNIST_large/B', 'notMNIST_large/C', 'notMNIST_large/D', 'notMNIST_large/E', 'notMNIST_large/F', 'notMNIST_large/G', 'notMNIST_large/H', 'notMNIST_large/I', 'notMNIST_large/J']
# Extracting data for notMNIST_small. This may take a while. Please wait.
# ['notMNIST_small/A', 'notMNIST_small/B', 'notMNIST_small/C', 'notMNIST_small/D', 'notMNIST_small/E', 'notMNIST_small/F', 'notMNIST_small/G', 'notMNIST_small/H', 'notMNIST_small/I', 'notMNIST_small/J']

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Let's take a peek at some of the data to make sure it looks sensible. Each exemplar should be an image of a character A through J rendered in a different font. Display a sample of the images that we just downloaded.
#
# **Hint**: you can use the package `IPython.display`.
#
# ---

# %%
def grab_sample(folder, num_images):
    """Grab a random sample of images and show them"""
    
    os.chdir(folder)
    # Get into that folder
    
    subfolder = os.listdir()[np.random.randint(0,len(os.listdir()))]
    # Pick a random subfolder

    os.chdir(subfolder)
    # Get in there
    
    image_files = [os.listdir()[i] for i in range(0,num_images)]
    # Pick a random set of image files
    
    current_folder()
    [display(Image(filename=i)) for i in image_files]
    # Show us what you picked
    
data_folder()
grab_sample('notMNIST_large',10)
data_folder()
# Out:
# Current folder: D

# %% [markdown]
# Now let's load the data in a more manageable format. Since, depending on your computer setup you might not be able to fit it all in memory, we'll load each class into a separate dataset, store them on disk and curate them independently. Later we'll merge them into a single dataset of manageable size.
#
# We'll convert the entire dataset into a **3D array (image index, x, y)** of floating point values, **normalized to have approximately zero mean and standard deviation ~0.5** to make training easier down the road.
#
# A few images might not be readable, we'll just skip them.

# %%
image_height = 28  # Pixel height (pre-defined)
image_width = 28 # Pixel width (pre-defined)
pixel_depth = 255.0  # Number of levels per pixel (pre-defined)

def load_letter(folder, min_num_images):   
    """Load the data for a single letter label."""
    os.chdir(folder)
    image_files = os.listdir()
    # Go into that subfolder and grab all the images 
    
    print('Creating a {} x {} x {} tensor to fill with normalized values between 0 and {}'.format(
        len(image_files), image_height, image_width, pixel_depth))
    dataset = np.ndarray(shape=(len(image_files), image_size, image_size),
                         dtype=np.float32)
    # Make a dataset to fill as long as the images, with the 
    # image_height, image_weidth, and holding float32 data
    
    num_images = 0    
    # Quick counter
    
    for image in image_files:
        print('On image {}.'.format(num_images))
        try: 
            image_data = (ndimage.imread(image).astype(float) - 
                          pixel_depth / 2) / pixel_depth
            
            # Read the image_data as a float, normalizing by subtracting (max_value/2) 
            # and dividing by max_value

            # Normalizing: 
            # We do this because sparce matrices (filled with 0s) are much easier on memory 
            # Since we subtract by half the max_value, we'll never be negative 
            # Values are forced into range between 0, and highest is max_value/2
            # We also divide by max_value to set them between 0 and 1 
            
            # Uncomment the following to see this in action:
            #not_normalized_image_data= ndimage.imread(image).astype(float)
            #print(not_normalized_image_data)
            #print(image_data)
            
            #if image_data.shape != (image_size, image_size):
            #    raise Exception('Unexpected image shape: %s' % str(image_data.shape))
            #dataset[num_images, :, :] = image_data
            #num_images = num_images + 1
            
            if image_data.shape != (image_size, image_size):
            # Is it the right shape (A 28 x 28 array) 
                raise Exception('Unexpected image shape: %s' % str(image_data.shape))


            print('Appending {} to dataset.'.format(image))
            # Tell us whats about to happen

            dataset[num_images, :, :] = image_data
            # Then do it

            num_images = num_images + 1
            # Update the counter
        
        
        except IOError as e:
            print('Could not read:', image_file, ':', e, ', skipping.')
        
        
    dataset = dataset[0:num_images, :, :]
    # Final dataset better be only as long as the images we appened

    if num_images < min_num_images:
    # Lets make sure we got the minimum number of images we wanted
        raise Exception('Many fewer images than expected: %d < %d' %
                        (num_images, min_num_images))
        # Raise an exception if not
        
            
    print('\n {} Dataset complete \n Mean: {} \n Standard Deviation: {}'.format(dataset.shape, 
                                                                              np.mean(dataset), np.std(dataset)))
    # Some descriptive stats on the new tensor 
    
    return dataset

data_folder()
dataset = load_letter(test_folders[2], 5)
# Out:
# Creating a 1873 x 28 x 28 tensor to fill with normalized values between 0 and 255.0
# On image 0.
# Appending MDEtMDEtMDAudHRm.png to dataset.
# On image 1.
# Appending MDRiXzA4LnR0Zg==.png to dataset.
# On image 2.
# Appending MjAwcHJvb2Ztb29uc2hpbmUgcmVtaXgudHRm.png to dataset.
# On image 3.
# Appending MlJlYmVsc0RldXgtQmxhY2sub3Rm.png to dataset.
# On image 4.
# Appending MlRvb24gU2hhZG93LnR0Zg==.png to dataset.
# On image 5.
# Appending MlRvb24yIFNoYWRvdy50dGY=.png to dataset.
# On image 6.
# Appending MTAuMTUgU2F0dXJkYXkgTmlnaHQgQlJLLnR0Zg==.png to dataset.
# On image 7.
# Appending MTFTMDEgQmxhY2sgVHVlc2RheSBPZmZzZXQudHRm.png to dataset.
# On image 8.
# Appending MTggSG9sZXMgQlJLLnR0Zg==.png to dataset.
# On image 9.
# Appending MTh0aENlbnR1cnkudHRm.png to dataset.
# On image 10.
# Appending MTIgV2FsYmF1bSBJdGFsaWMgMTMyNjMudHRm.png to dataset.
# On image 11.
# Appending MTJTYXJ1WWVsbG93Rm9nLnR0Zg==.png to dataset.
# On image 12.
# Appending Nng3b2N0IEFsdGVybmF0ZSBFeHRyYUxpZ2h0LnR0Zg==.png to dataset.
# On image 13.
# Appending Nng3b2N0IEFsdGVybmF0ZSBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 14.
# Appending NXRoR3JhZGVyLnR0Zg==.png to dataset.
# On image 15.
# Appending OC1iaXQgTGltaXQgTyBCUksudHRm.png to dataset.
# On image 16.
# Appending OEJhbGxTY3JpcHRTQ2Fwc1NTSyBJdGFsaWMudHRm.png to dataset.
# On image 17.
# Appending OTExIFBvcnNjaGEgSXRhbGljLnR0Zg==.png to dataset.
# On image 18.
# Appending OXNxZ3JkIFRoaW4udHRm.png to dataset.
# On image 19.
# Appending Q09ERTNYLnR0Zg==.png to dataset.
# On image 20.
# Appending Q0cgT21lZ2EudHRm.png to dataset.
# On image 21.
# Appending Q0NDb21pY3JhenktQm9sZEl0YWxpYy50dGY=.png to dataset.
# On image 22.
# Appending Q0NTcG9va3l0b290aC1SZWd1bGFyLnR0Zg==.png to dataset.
# On image 23.
# Appending Q0NXaWxkV29yZHMtQm9sZEl0YWxpYy50dGY=.png to dataset.
# On image 24.
# Appending Q0sgUGluay50dGY=.png to dataset.
# On image 25.
# Appending Q1FOLU1vbGVjdWxhci1EeW5hbW8tUmVndWxhci5vdGY=.png to dataset.
# On image 26.
# Appending Q290cmFuIERpc3BsYXkgU1NpLnR0Zg==.png to dataset.
# On image 27.
# Appending Q291bnRyeXNpZGUgQmxhY2sgU1NpIEV4dHJhIEJvbGQudHRm.png to dataset.
# On image 28.
# Appending Q291cmllci1Cb2xkLm90Zg==.png to dataset.
# On image 29.
# Appending Q291cmllci1Cb2xkT2JsaXF1ZS5vdGY=.png to dataset.
# On image 30.
# Appending Q291cmllciAxMCBQaXRjaCBJdGFsaWMucGZi.png to dataset.
# On image 31.
# Appending Q291cmllciBOZXcgQ0UgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 32.
# Appending Q291cmllcjEwIEJUIEl0YWxpYy50dGY=.png to dataset.
# On image 33.
# Appending Q291cmllcjEwIEJUIFJvbWFuLnR0Zg==.png to dataset.
# On image 34.
# Appending Q291cmllcjEwUGl0Y2hCVC1JdGFsaWMub3Rm.png to dataset.
# On image 35.
# Appending Q291cmllckMtQm9sZC5vdGY=.png to dataset.
# On image 36.
# Appending Q291cmllckMtT2JsaXF1ZS5vdGY=.png to dataset.
# On image 37.
# Appending Q291Y2hsb3Zlcjk3LnR0Zg==.png to dataset.
# On image 38.
# Appending Q292aW5ndG9uIENvbmQgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 39.
# Appending Q292aW5ndG9uIFNoYWRvdyBJdGFsaWMudHRm.png to dataset.
# On image 40.
# Appending Q29hZ3VsYXRlLnR0Zg==.png to dataset.
# On image 41.
# Appending Q29iYWx0IE5vcm1hbC50dGY=.png to dataset.
# On image 42.
# Appending Q29jaGluIExULnR0Zg==.png to dataset.
# On image 43.
# Appending Q29jb24tUmVndWxhci5vdGY=.png to dataset.
# On image 44.
# Appending Q29jb2EgVGhpbiBOb3JtYWwudHRm.png to dataset.
# On image 45.
# Appending Q29jYWluZSBTYW5zLnR0Zg==.png to dataset.
# On image 46.
# Appending Q29lcmNpb25OYWtlZC50dGY=.png to dataset.
# On image 47.
# Appending Q29mZmVlIFNob3AudHRm.png to dataset.
# On image 48.
# Appending Q29sb255Lm90Zg==.png to dataset.
# On image 49.
# Appending Q29sb3NzYWxpcy1CbGFjay5vdGY=.png to dataset.
# On image 50.
# Appending Q29sbWNpbGxlTVRTdGQtUmVndWxhci5vdGY=.png to dataset.
# On image 51.
# Appending Q29sdW1iaWEtQm9sZC5vdGY=.png to dataset.
# On image 52.
# Appending Q29sdW1idXNNVFN0ZC1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 53.
# Appending Q29seW1waWEtRGVtaUJvbGQub3Rm.png to dataset.
# On image 54.
# Appending Q29seW1waWEtTGlnaHQub3Rm.png to dataset.
# On image 55.
# Appending Q29sZGJyaW5nZXIgS0cudHRm.png to dataset.
# On image 56.
# Appending Q29taWNCb29rLm90Zg==.png to dataset.
# On image 57.
# Appending Q29taXggUmVndWxhcigxKS50dGY=.png to dataset.
# On image 58.
# Appending Q29tb25zIEJvbGQudHRm.png to dataset.
# On image 59.
# Appending Q29tbWVyY2lhbFNjcmlwdC5vdGY=.png to dataset.
# On image 60.
# Appending Q29tbWVyY2UgQ29uZGVuc2VkIFNTaSBDb25kZW5zZWQgSXRhbGljLnR0Zg==.png to dataset.
# On image 61.
# Appending Q29tbWVyY2UgQmxhY2sgU1NpIEJvbGQudHRm.png to dataset.
# On image 62.
# Appending Q29tbWVyY2UgU1NpIFNlbWkgQm9sZC50dGY=.png to dataset.
# On image 63.
# Appending Q29tbXVuaXR5U2VydmljZSBCbGFjay50dGY=.png to dataset.
# On image 64.
# Appending Q29tc2F0LU5hdnktVW5pdC5vdGY=.png to dataset.
# On image 65.
# Appending Q29tc2F0LVN0YXRpb24ub3Rm.png to dataset.
# On image 66.
# Appending Q29tc2F0LVVuaXQub3Rm.png to dataset.
# On image 67.
# Appending Q29tcGF0aWxGYWN0IExUIFJlZ3VsYXIgU21hbGwgQ2Fwcy50dGY=.png to dataset.
# On image 68.
# Appending Q29tcGF0aWxMZXR0ZXIgTFQgQm9sZCBTbWFsbCBDYXBzLnR0Zg==.png to dataset.
# On image 69.
# Appending Q29tcGF0aWxMZXR0ZXIgTFQgUmVndWxhciBTbWFsbCBDYXBzLnR0Zg==.png to dataset.
# On image 70.
# Appending Q29tcGF0aWxUZXh0IExUIFJlZ3VsYXIgU21hbGwgQ2Fwcy50dGY=.png to dataset.
# On image 71.
# Appending Q29tcGFjdEMtQm9sZEl0YWxpYy5vdGY=.png to dataset.
# On image 72.
# Appending Q29tcGFjdGEgQmxhY2sgQlQudHRm.png to dataset.
# On image 73.
# Appending Q29tcGFjdGEgQmxhY2sucGZi.png to dataset.
# On image 74.
# Appending Q29tcGFjdGEgSUNHIEJvbGRJdGFsaWMudHRm.png to dataset.
# On image 75.
# Appending Q29tcGFjdGEucGZi.png to dataset.
# On image 76.
# Appending Q29tcGFjdGFFRi1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 77.
# Appending Q29tcGFjdGFFRi1MaWdodC5vdGY=.png to dataset.
# On image 78.
# Appending Q29tcGFjdGFTdGQtQm9sZC5vdGY=.png to dataset.
# On image 79.
# Appending Q29tcGVuZGl1bSBCbGFjayBTU2kgQmxhY2sudHRm.png to dataset.
# On image 80.
# Appending Q29tcHJlc3Nvci1TbGFiU2VyaWYub3Rm.png to dataset.
# On image 81.
# Appending Q29tcHV0ZXJmb250LnR0Zg==.png to dataset.
# On image 82.
# Appending Q29tZW5pdXNCUS1NZWRpdW0ub3Rm.png to dataset.
# On image 83.
# Appending Q29uc29sYXMgSXRhbGljLnR0Zg==.png to dataset.
# On image 84.
# Appending Q29uc3RhbnRpYS50dGY=.png to dataset.
# On image 85.
# Appending Q29uc3RydWN0aXZpc3QgU29saWQudHRm.png to dataset.
# On image 86.
# Appending Q29uc3RydWN0YS1UaGluLm90Zg==.png to dataset.
# On image 87.
# Appending Q29ucXVpc3RhIFNTaSBJdGFsaWMudHRm.png to dataset.
# On image 88.
# Appending Q29udGludXVtIEJvbGQudHRm.png to dataset.
# On image 89.
# Appending Q29udGluZW50YWxSYWlsd2F5LnBmYg==.png to dataset.
# On image 90.
# Appending Q29udGV4dCBSZXByaXNlIE1lZGl1bSBTU2kgTWVkaXVtLnR0Zg==.png to dataset.
# On image 91.
# Appending Q29udGV4dCBSZXByaXNlIENvbmRlbnNlZCBTU2kgQ29uZGVuc2VkLnR0Zg==.png to dataset.
# On image 92.
# Appending Q29udGV4dCBSZXByaXNlIFRoaW4gU1NpIFRoaW4udHRm.png to dataset.
# On image 93.
# Appending Q29udGV4dCBTU2kgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 94.
# Appending Q29udGV4dCBTZW1pIENvbmRlbnNlZCBTU2kgU2VtaSBDb25kZW5zZWQudHRm.png to dataset.
# On image 95.
# Appending Q29udHJvbCBGcmVhayBPZmZzZXQudHRm.png to dataset.
# On image 96.
# Appending Q29uY29yZGlhU1NLIEJvbGQudHRm.png to dataset.
# On image 97.
# Appending Q29uY29yZGUgTm92YSAoUikgRXhwZXJ0IEl0YWxpYyBPc0YudHRm.png to dataset.
# On image 98.
# Appending Q29uY29yZGVCRS1Cb2xkQ24ub3Rm.png to dataset.
# On image 99.
# Appending Q29uY29yZGVFeHBlcnRCUS1JdGFsaWNPc0Yub3Rm.png to dataset.
# On image 100.
# Appending Q29uY29yZGVFeHBlcnRCUS1NZWRpdW0ub3Rm.png to dataset.
# On image 101.
# Appending Q29uY3Vyc29JdGFsaWFuIEJUTiBCb2xkLnR0Zg==.png to dataset.
# On image 102.
# Appending Q29uY3Vyc29JdGFsaWFuIEJUTiBMaW5lZCBPYmxpcXVlLnR0Zg==.png to dataset.
# On image 103.
# Appending Q29uY3Vyc29Nb2Rlcm5lIEJUTiBMdC50dGY=.png to dataset.
# On image 104.
# Appending Q29uY3Vyc29Nb2Rlcm5lIEJUTiBXaWRlIE9ibGlxdWUudHRm.png to dataset.
# On image 105.
# Appending Q29uZHVpdE9TSVRDLUxpZ2h0Lm90Zg==.png to dataset.
# On image 106.
# Appending Q29vcEZvcmdlZC5wZmI=.png to dataset.
# On image 107.
# Appending Q29vcGVyIEJsayBCVCBCbGFjay50dGY=.png to dataset.
# On image 108.
# Appending Q29vcGVyIEl0YWxpYy50dGY=.png to dataset.
# On image 109.
# Appending Q29vcGVyLnR0Zg==.png to dataset.
# On image 110.
# Appending Q29vcGVyQlQtQmxhY2tIZWFkbGluZS5vdGY=.png to dataset.
# On image 111.
# Appending Q29vcGVyQmxhRCBJdGFsaWMudHRm.png to dataset.
# On image 112.
# Appending Q29wcGVycGxhdGUgQ29uZGVuc2VkIFNTaSBDb25kZW5zZWQudHRm.png to dataset.
# On image 113.
# Appending Q29wcGVycGxhdGUgRXh0cmEgQ29uZGVuc2VkIFNTaSBCb2xkIEV4dHJhIENvbmRlbnNlZC50dGY=.png to dataset.
# On image 114.
# Appending Q29wcGVycGxhdGUudHRm.png to dataset.
# On image 115.
# Appending Q29wcGVycGxhdGVCUS1IZWF2eUV4dGVuZGVkLm90Zg==.png to dataset.
# On image 116.
# Appending Q29wcGVycGxhdGVFRi1MaWdodC5vdGY=.png to dataset.
# On image 117.
# Appending Q29wcGVycGxhdGVHb3RoaWNTdGQtMzJCQy5vdGY=.png to dataset.
# On image 118.
# Appending Q29wcGVycGxhdGVULUJvbGRDb25kZW5zZWQub3Rm.png to dataset.
# On image 119.
# Appending Q29weTA5NjUudHRm.png to dataset.
# On image 120.
# Appending Q29wYSBTaGFycCBCVE4gU2hhZG93LnR0Zg==.png to dataset.
# On image 121.
# Appending Q29yaW50aGlhbi50dGY=.png to dataset.
# On image 122.
# Appending Q29yb25ldC1TZW1pQm9sZC1JdGFsaWMgRXgudHRm.png to dataset.
# On image 123.
# Appending Q29yb25ldC50dGY=.png to dataset.
# On image 124.
# Appending Q29ybmV0IFNjcmlwdC50dGY=.png to dataset.
# On image 125.
# Appending Q29ycG9BLnR0Zg==.png to dataset.
# On image 126.
# Appending Q29ycG9TLnR0Zg==.png to dataset.
# On image 127.
# Appending Q29ycG9TTGlnIEJvbGQudHRm.png to dataset.
# On image 128.
# Appending Q29ycG9yYXRlIEEgRXhwZXJ0IEl0YWxpYyBPc0YudHRm.png to dataset.
# On image 129.
# Appending Q29ycG9yYXRlIEEgRXhwZXJ0IExpZ2h0LnR0Zg==.png to dataset.
# On image 130.
# Appending Q29ycG9yYXRlIEhRLnR0Zg==.png to dataset.
# On image 131.
# Appending Q29ycG9yYXRlIEUga3Vyc2l2IGhhbGJmZXR0LnR0Zg==.png to dataset.
# On image 132.
# Appending Q29ycG9yYXRlIFMgRXhwZXJ0IEV4dHJhIEJvbGQgSXRhbGljIE9zRi50dGY=.png to dataset.
# On image 133.
# Appending Q29ycG9yYXRlIFMgUmVndWxhci50dGY=.png to dataset.
# On image 134.
# Appending Q29ycG9yYXRlQVNDLUJvbGQub3Rm.png to dataset.
# On image 135.
# Appending Q29ycG9yYXRlRUV4cGVydEJRLUJvbGRJdGFsaWNPc0Yub3Rm.png to dataset.
# On image 136.
# Appending Q29ycG9yYXRlU0V4cGVydEJRLUxpZ2h0Lm90Zg==.png to dataset.
# On image 137.
# Appending Q29ycG9yYXRlUy1EZW1pSXRhbGljLm90Zg==.png to dataset.
# On image 138.
# Appending Q29ycGlkLUxpZ2h0SXRhbGljLm90Zg==.png to dataset.
# On image 139.
# Appending Q29ycGlkQ2RMRi1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 140.
# Appending Q29ycGlkQ2RMRi1MaWdodC5vdGY=.png to dataset.
# On image 141.
# Appending Q29ydGluLnR0Zg==.png to dataset.
# On image 142.
# Appending Q29yYmVpIFVuY2lhbC50dGY=.png to dataset.
# On image 143.
# Appending Q29yZGlhIE5ldyBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 144.
# Appending Q29yZGlhVVBDLnR0Zg==.png to dataset.
# On image 145.
# Appending Q29zbW9zQlEtTGlnaHRJdGFsaWMub3Rm.png to dataset.
# On image 146.
# Appending Q29zdGFQdGYtRGVtaS5vdGY=.png to dataset.
# On image 147.
# Appending Q29zdGFQdGYtRXh0cmFCb2xkLm90Zg==.png to dataset.
# On image 148.
# Appending Q2dFZ2l6aWFub0JsLnR0Zg==.png to dataset.
# On image 149.
# Appending Q2dGaWVkbGVyR290aGljLUJvbGQudHRm.png to dataset.
# On image 150.
# Appending Q2dGdXR1cmFNYXhpTHQudHRm.png to dataset.
# On image 151.
# Appending Q2dNb2Rlcm5Ud2VudHkudHRm.png to dataset.
# On image 152.
# Appending Q2dQaGVuaXhBbWVyaWNhbi50dGY=.png to dataset.
# On image 153.
# Appending Q2dZZWFyYm9va091dGxpbmUudHRm.png to dataset.
# On image 154.
# Appending Q2dZZWFyYm9va0ZpbGxlci50dGY=.png to dataset.
# On image 155.
# Appending Q2F0aGFyc2lzIENhcmdvLnR0Zg==.png to dataset.
# On image 156.
# Appending Q2F0dWxsIChSKSBNZWRpdSBPc0YudHRm.png to dataset.
# On image 157.
# Appending Q2F2ZSBHeXJsLnR0Zg==.png to dataset.
# On image 158.
# Appending Q2F4dG9uIEJvbGQgSXRhbGljLnBmYg==.png to dataset.
# On image 159.
# Appending Q2F4dG9uIExpZ2h0IEl0YWxpYyBCVC50dGY=.png to dataset.
# On image 160.
# Appending Q2F4dG9uLUJvbGRJdGFsaWMub3Rm.png to dataset.
# On image 161.
# Appending Q2F4dG9uU3RkLUJvbGRJdGFsaWMub3Rm.png to dataset.
# On image 162.
# Appending Q2FiYXJnYUN1cnNJQ0cub3Rm.png to dataset.
# On image 163.
# Appending Q2Fjb3Bob255IExvdWQudHRm.png to dataset.
# On image 164.
# Appending Q2FlY2lsaWEtSGVhdnlJdGFsaWNPc0Yub3Rm.png to dataset.
# On image 165.
# Appending Q2FlY2lsaWEtTGlnaHRJdGFsaWMub3Rm.png to dataset.
# On image 166.
# Appending Q2FlY2lsaWFMVFN0ZC1MaWdodC5vdGY=.png to dataset.
# On image 167.
# Appending Q2FmZU5vaXJTaGFkb3cudHRm.png to dataset.
# On image 168.
# Appending Q2Fpcm9FeHRlbmRlZEl0YWxpYyBJdGFsaWMudHRm.png to dataset.
# On image 169.
# Appending Q2FsaWd1bGEgUmVndWxhci50dGY=.png to dataset.
# On image 170.
# Appending Q2FsaXBlciBXaWRlLnR0Zg==.png to dataset.
# On image 171.
# Appending Q2FsaXMgaW4gUHVwcGV0bGFuZC50dGY=.png to dataset.
# On image 172.
# Appending Q2FsbGlncmFwaDgxMCBCVCBSb21hbi50dGY=.png to dataset.
# On image 173.
# Appending Q2Fsdmlub0hhbmQudHRm.png to dataset.
# On image 174.
# Appending Q2FsdmVydCBNVCBCb2xkLnR0Zg==.png to dataset.
# On image 175.
# Appending Q2FsdmVydCBNVCBMaWdodC50dGY=.png to dataset.
# On image 176.
# Appending Q2FsdmVydE1ULm90Zg==.png to dataset.
# On image 177.
# Appending Q2FsY3VsdXNMQ0RDYW1lby5vdGY=.png to dataset.
# On image 178.
# Appending Q2FsYW1pdHkgVGVlbiBCVE4gQm9sZC50dGY=.png to dataset.
# On image 179.
# Appending Q2FsZ2FyeS1MaWdodC5vdGY=.png to dataset.
# On image 180.
# Appending Q2FtYnJpZGdlLURlbWlCb2xkLm90Zg==.png to dataset.
# On image 181.
# Appending Q2FtYnJpZGdlLUxpZ2h0Lm90Zg==.png to dataset.
# On image 182.
# Appending Q2FtZWxpYSBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 183.
# Appending Q2FtZWxsaWFELnR0Zg==.png to dataset.
# On image 184.
# Appending Q2FudG9yaWEgTVQgRXh0cmFCb2xkLnR0Zg==.png to dataset.
# On image 185.
# Appending Q2FudG9yaWFNVFN0ZC1Cb2xkLm90Zg==.png to dataset.
# On image 186.
# Appending Q2FudXRoLnR0Zg==.png to dataset.
# On image 187.
# Appending Q2FuY2VsbGFyZXNjYSBTY3JpcHQudHRm.png to dataset.
# On image 188.
# Appending Q2FuY2VsbGFyZXNjYVNjcmlwdFBsYWluLm90Zg==.png to dataset.
# On image 189.
# Appending Q2FuYWRpYW5QaG90b2dyYXBoZXIub3Rm.png to dataset.
# On image 190.
# Appending Q2FuZGlkYSBCVCBJdGFsaWMudHRm.png to dataset.
# On image 191.
# Appending Q2FuZGlkYUJULUl0YWxpYy5vdGY=.png to dataset.
# On image 192.
# Appending Q2FuZHkgQ2FuZSBNYXRjaC50dGY=.png to dataset.
# On image 193.
# Appending Q2FuZHkgU3F1YXJlIEJUTiBDb25kLnR0Zg==.png to dataset.
# On image 194.
# Appending Q2FuZHkgU3RyaXBlIChCUkspLnR0Zg==.png to dataset.
# On image 195.
# Appending Q2FwaXRhbHMudHRm.png to dataset.
# On image 196.
# Appending Q2FwdGFpbiBTaGluZXIudHRm.png to dataset.
# On image 197.
# Appending Q2Fyb2xzQ2h1bmtzLnR0Zg==.png to dataset.
# On image 198.
# Appending Q2FybGEgQm9sZC50dGY=.png to dataset.
# On image 199.
# Appending Q2FybGlzbGUgUmVndWxhci50dGY=.png to dataset.
# On image 200.
# Appending Q2FybmF0aSBTU2kgSXRhbGljLnR0Zg==.png to dataset.
# On image 201.
# Appending Q2Fybml2YWwub3Rm.png to dataset.
# On image 202.
# Appending Q2FybWluYSBNZCBCVCBNZWRpdW0udHRm.png to dataset.
# On image 203.
# Appending Q2FycGFsIFR1bm5lbC50dGY=.png to dataset.
# On image 204.
# Appending Q2FycmVOb2lyU3RkLUJvbGRJdGFsaWMub3Rm.png to dataset.
# On image 205.
# Appending Q2FydG9vbiBXaWRlLnR0Zg==.png to dataset.
# On image 206.
# Appending Q2FydGllckJvb2tTdGQtTWVkaXVtLm90Zg==.png to dataset.
# On image 207.
# Appending Q2FyYm9uIEJsb2NrLnR0Zg==.png to dataset.
# On image 208.
# Appending Q2FyZ28gVHdvIFNGLnR0Zg==.png to dataset.
# On image 209.
# Appending Q2FyZ29ELnR0Zg==.png to dataset.
# On image 210.
# Appending Q2FyZGluYWwgUmVndWxhci50dGY=.png to dataset.
# On image 211.
# Appending Q2FzaEVGLU1vbm9zcGFjZS5vdGY=.png to dataset.
# On image 212.
# Appending Q2FzbG9uIDU0MCBJdGFsaWMucGZi.png to dataset.
# On image 213.
# Appending Q2FzbG9uIEJvb2sgQkUgQm9sZC50dGY=.png to dataset.
# On image 214.
# Appending Q2FzbG9uIENhbGxpZ3JhcGhpYyBJbml0aWFscy50dGY=.png to dataset.
# On image 215.
# Appending Q2FzbG9uMjI0SVRDYnlCVC1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 216.
# Appending Q2FzbG9uQm9va0JFLUJvbGRPc0Yub3Rm.png to dataset.
# On image 217.
# Appending Q2FzbG9uQm9vay5vdGY=.png to dataset.
# On image 218.
# Appending Q2FzbG9uQzM3LUxndEl0bEFsdC5vdGY=.png to dataset.
# On image 219.
# Appending Q2FzbG9uSC1TQy1JdGFsaWMub3Rm.png to dataset.
# On image 220.
# Appending Q2FzbG9uSUNHLVRpdGxpbmcub3Rm.png to dataset.
# On image 221.
# Appending Q2FzbG9uT2xkRmFjZSBCVCBSb21hbi50dGY=.png to dataset.
# On image 222.
# Appending Q2FzbG9uT2xkRmFjZUJULVJvbWFuLm90Zg==.png to dataset.
# On image 223.
# Appending Q2FzbG9uVHdvVHdlbnR5Rm91ci1CbGFja0l0Lm90Zg==.png to dataset.
# On image 224.
# Appending Q2FzbG9uVHdvVHdlbnR5Rm91ci1NZWRpdW0ub3Rm.png to dataset.
# On image 225.
# Appending Q2FzbG9uVHdvVHdlbnR5Rm91ckJRLU1lZGl1bS5vdGY=.png to dataset.
# On image 226.
# Appending Q2Fzc2FuZHJhLnR0Zg==.png to dataset.
# On image 227.
# Appending Q2Fzc2FuZHJhRUYtQm9sZC5vdGY=.png to dataset.
# On image 228.
# Appending Q2FzdG9yZ2F0ZSAtIE1lc3NlZC50dGY=.png to dataset.
# On image 229.
# Appending Q2FzdG9yZ2F0ZSAtIFJvdWdoLnR0Zg==.png to dataset.
# On image 230.
# Appending Q2FzdGxlVC1Cb2xkLm90Zg==.png to dataset.
# On image 231.
# Appending Q2FzdWFsLnR0Zg==.png to dataset.
# On image 232.
# Appending Q2FzIE9wZW4gRmFjZSBOb3JtYWwudHRm.png to dataset.
# On image 233.
# Appending Q2FzYWJsYW4tRXh0cmFCb2xkLm90Zg==.png to dataset.
# On image 234.
# Appending Q2h1cmNod2FyZEJydURSZWcudHRm.png to dataset.
# On image 235.
# Appending Q2h1YmJ5T3V0bGluZS50dGY=.png to dataset.
# On image 236.
# Appending Q2hhbGV0Qm9vayBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 237.
# Appending Q2hhbGV0Qm9vayBCb2xkLm90Zg==.png to dataset.
# On image 238.
# Appending Q2hhbmNlcnkgU2NyaXB0IE1lZGl1bSBTU2kgTWVkaXVtLnR0Zg==.png to dataset.
# On image 239.
# Appending Q2hhbmV5IEV4dGVuZGVkIE5vcm1hbC50dGY=.png to dataset.
# On image 240.
# Appending Q2hhbnNvbiBIZWF2eSBTRiBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 241.
# Appending Q2hhbnRpbGx5LU1lZGl1bS5vdGY=.png to dataset.
# On image 242.
# Appending Q2hhbnRpbGx5LVhsaWdodEl0YS5vdGY=.png to dataset.
# On image 243.
# Appending Q2hhbXBhZ25lSXRhbGljLm90Zg==.png to dataset.
# On image 244.
# Appending Q2hhc2xpbmUtQm9sZC5vdGY=.png to dataset.
# On image 245.
# Appending Q2hhc2xpbmUtT2JsaXF1ZS5vdGY=.png to dataset.
# On image 246.
# Appending Q2hhcGFycmFsUHJvLUxpZ2h0SXRDYXB0Lm90Zg==.png to dataset.
# On image 247.
# Appending Q2hhcmxpZSdzIEFuZ2xlcyBPdXRHcmFkaWVudC50dGY=.png to dataset.
# On image 248.
# Appending Q2hhcmxvdHRlU3RkLUJvb2sub3Rm.png to dataset.
# On image 249.
# Appending Q2hhcnJpbmd0b24gV2lkZS50dGY=.png to dataset.
# On image 250.
# Appending Q2hhcnRlciBJVEMgQm9sZCBCVC50dGY=.png to dataset.
# On image 251.
# Appending Q2hhcnRlciBJVEMgSXRhbGljIEJULnR0Zg==.png to dataset.
# On image 252.
# Appending Q2hhcnRlciBJVEMgUm9tYW4gQlQudHRm.png to dataset.
# On image 253.
# Appending Q2hhcnRlciBPU0YgQlQgQmxhY2sgSXRhbGljLnR0Zg==.png to dataset.
# On image 254.
# Appending Q2hhcnRlcklUQ2J5QlQtQm9sZEl0YWxpYy5vdGY=.png to dataset.
# On image 255.
# Appending Q2hhcnRlcklUQy1SZWd1SXRhbC5vdGY=.png to dataset.
# On image 256.
# Appending Q2hhcnRlckVGLVJlZ3VsYXJJdGFsaWNPc0Yub3Rm.png to dataset.
# On image 257.
# Appending Q2hheiBXaWRlIE5vcm1hbC50dGY=.png to dataset.
# On image 258.
# Appending Q2hlbHNleSBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 259.
# Appending Q2hlbHNleSBDb25kZW5zZWQgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 260.
# Appending Q2hlbHNleSBFeHRlbmRlZCBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 261.
# Appending Q2hlbHNleSBXaWRlIE5vcm1hbC50dGY=.png to dataset.
# On image 262.
# Appending Q2hlbHNlYS1Cb29rLm90Zg==.png to dataset.
# On image 263.
# Appending Q2hlbHRlbmhhbS1Cb29rQ29uZEl0YWxpYy5vdGY=.png to dataset.
# On image 264.
# Appending Q2hlbHRlbmhhbS1Cb2xkQ29uZEl0YWxpYy5vdGY=.png to dataset.
# On image 265.
# Appending Q2hlbHRlbmhhbS1VbHRyYUNvbmQub3Rm.png to dataset.
# On image 266.
# Appending Q2hlbHRlbmhhbSBCb2xkIEl0YWxpYyBCVC50dGY=.png to dataset.
# On image 267.
# Appending Q2hlbHRlbmhhbSBJdGFsaWMucGZi.png to dataset.
# On image 268.
# Appending Q2hlbHRlbmhhbSBJdGMgVCBFRSBCb2xkLnBmYg==.png to dataset.
# On image 269.
# Appending Q2hlbHRlbmhhbU9sZFN0eWxlRUYub3Rm.png to dataset.
# On image 270.
# Appending Q2hlbHRlbmhhbUFURk9sZHN0eWxlQlEtSXRhbGljLm90Zg==.png to dataset.
# On image 271.
# Appending Q2hlbHRlbmhhbUJULUl0YWxpYy5vdGY=.png to dataset.
# On image 272.
# Appending Q2hlbHRlbmhhbUlUQ0JRLUJvb2sub3Rm.png to dataset.
# On image 273.
# Appending Q2hlbHRlbmhhbUlUQ2J5QlQtQm9va0l0YWxpYy5vdGY=.png to dataset.
# On image 274.
# Appending Q2hlbHRlbmhhbVN0ZC1Cb2xkLm90Zg==.png to dataset.
# On image 275.
# Appending Q2hlbHRlbmhtIEJUIEJvbGQudHRm.png to dataset.
# On image 276.
# Appending Q2hlbHRlbmhtIEJUIEl0YWxpYy50dGY=.png to dataset.
# On image 277.
# Appending Q2hlbHRlbmhtIEJUIFJvbWFuLnR0Zg==.png to dataset.
# On image 278.
# Appending Q2hlbHRlbmhtIFhCZENuIEJUIEJvbGQudHRm.png to dataset.
# On image 279.
# Appending Q2hlbmdhbHVsdS5vdGY=.png to dataset.
# On image 280.
# Appending Q2hlbWljYWwgUmVhY3Rpb24gQiAtQlJLLS50dGY=.png to dataset.
# On image 281.
# Appending Q2hlc3RlcmZpZWxkQW50RC50dGY=.png to dataset.
# On image 282.
# Appending Q2hlcmllIElUQy50dGY=.png to dataset.
# On image 283.
# Appending Q2hldmFsaWVyQ2Fwc0JRLVJlZ3VsYXIub3Rm.png to dataset.
# On image 284.
# Appending Q2hldmFsaWVyU3RyU0NELnR0Zg==.png to dataset.
# On image 285.
# Appending Q2hpbGFkYUlDRy1Vbm8ub3Rm.png to dataset.
# On image 286.
# Appending Q2hpbGQncyBQbGF5LnR0Zg==.png to dataset.
# On image 287.
# Appending Q2hpbGRzUGxheS1BZ2VOaW5lLm90Zg==.png to dataset.
# On image 288.
# Appending Q2hpbmVzZSBCcnVzaC50dGY=.png to dataset.
# On image 289.
# Appending Q2hpbnllbiAgTm9ybWFsLnR0Zg==.png to dataset.
# On image 290.
# Appending Q2hpc2VsIFdpZGUgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 291.
# Appending Q2hpc2VsIFdpZGUgSXRhbGljLnR0Zg==.png to dataset.
# On image 292.
# Appending Q2hpc2VsIFRoaW4gQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 293.
# Appending Q2hpY29yeS50dGY=.png to dataset.
# On image 294.
# Appending Q2hpY2Fnb0xhc2VyIE1lZGl1bS50dGY=.png to dataset.
# On image 295.
# Appending Q2hpY2FuZSBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 296.
# Appending Q2hpYW50aSBHWCBCVC50dGY=.png to dataset.
# On image 297.
# Appending Q2hpYW50aSBYQmRJdCBPU0YgQlQgRXh0cmEgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 298.
# Appending Q2hvcml6by50dGY=.png to dataset.
# On image 299.
# Appending Q2hvcmQtQmxhY2sub3Rm.png to dataset.
# On image 300.
# Appending Q2hvcmQtQmxhY2tJdGFsaWMub3Rm.png to dataset.
# On image 301.
# Appending Q2hvcmVhIERpc3BsYXkgU1NpIEJsYWNrLnR0Zg==.png to dataset.
# On image 302.
# Appending Q2hvd2RlcmhlYWQudHRm.png to dataset.
# On image 303.
# Appending Q2hvY0lDRy5vdGY=.png to dataset.
# On image 304.
# Appending Q2hvZGEudHRm.png to dataset.
# On image 305.
# Appending Q2hyaXN0b3Boc1F1aWxsSVRDU3RkLUJvbGQub3Rm.png to dataset.
# On image 306.
# Appending Q2hyaXN0bWFzR2lmdFNjcmlwdEEudHRm.png to dataset.
# On image 307.
# Appending Q2hyaXN0bWFzR2lmdFNjcmlwdEJvbGRBLnR0Zg==.png to dataset.
# On image 308.
# Appending Q2hyb21lWWVsbG93LnR0Zg==.png to dataset.
# On image 309.
# Appending Q2hyb21vc29tZVJldmVyc2VkLUhlYXZ5Lm90Zg==.png to dataset.
# On image 310.
# Appending Q2l0aXplbkxpZ2h0IFJlZ3VsYXIudHRm.png to dataset.
# On image 311.
# Appending Q2l0aXplbkxpZ2h0Lm90Zg==.png to dataset.
# On image 312.
# Appending Q2l0eS1MaWdodC5vdGY=.png to dataset.
# On image 313.
# Appending Q2l0eSAoUikgTGlnaHQudHRm.png to dataset.
# On image 314.
# Appending Q2l0eURFRU1lZC50dGY=.png to dataset.
# On image 315.
# Appending Q2l0YWRlbC1JbmxpbmUub3Rm.png to dataset.
# On image 316.
# Appending Q2lyY3VsYXIgRkMudHRm.png to dataset.
# On image 317.
# Appending Q2lyY3VsYXRlIChCUkspLnR0Zg==.png to dataset.
# On image 318.
# Appending Q2lyY3VtY2lzaW9uLUJvbGQub3Rm.png to dataset.
# On image 319.
# Appending Q2lyY3VzIE5vcm1hbC50dGY=.png to dataset.
# On image 320.
# Appending Q2VubmVyaWsgUGxhaW4udHRm.png to dataset.
# On image 321.
# Appending Q2VudG8gRXh0ZW5kZWQgQm9sZEl0YWxpYy50dGY=.png to dataset.
# On image 322.
# Appending Q2VudGF1ci1EZW1pQm9sZC5vdGY=.png to dataset.
# On image 323.
# Appending Q2VudGVubmlhbC1CbGFjay5vdGY=.png to dataset.
# On image 324.
# Appending Q2VudHVyeS1Cb29rLm90Zg==.png to dataset.
# On image 325.
# Appending Q2VudHVyeS1TY2hvb2xib29rLU5vcm1hbC50dGY=.png to dataset.
# On image 326.
# Appending Q2VudHVyeS1VbHRyYUl0YWxpYy5vdGY=.png to dataset.
# On image 327.
# Appending Q2VudHVyeSA3MjUgQ29uZGVuc2VkIEJULnR0Zg==.png to dataset.
# On image 328.
# Appending Q2VudHVyeSA3MzEgQm9sZC5wZmI=.png to dataset.
# On image 329.
# Appending Q2VudHVyeSA3NTEgQm9sZCBJdGFsaWMucGZi.png to dataset.
# On image 330.
# Appending Q2VudHVyeSBFeHBhbmRlZCBJdGFsaWMucGZi.png to dataset.
# On image 331.
# Appending Q2VudHVyeSBHb3RoaWMudHRm.png to dataset.
# On image 332.
# Appending Q2VudHVyeSBPbGRzdHlsZS5wZmI=.png to dataset.
# On image 333.
# Appending Q2VudHVyeSBSZXRyb3NwZWN0aXZlIExpZ2h0IFNTaSBMaWdodCBJdGFsaWMudHRm.png to dataset.
# On image 334.
# Appending Q2VudHVyeSBTY2hvb2xib29rIEdyZWVrIEJULnR0Zg==.png to dataset.
# On image 335.
# Appending Q2VudHVyeSBTY2hvb2xib29rIEdyZWVrIEJvbGQgSW5jbGluZWQgQlQudHRm.png to dataset.
# On image 336.
# Appending Q2VudHVyeSBTY2hvb2xib29rIEdyZWVrIEluY2xpbmVkIEJULnR0Zg==.png to dataset.
# On image 337.
# Appending Q2VudHVyeSBTY2hvb2xib29rIEJvbGQgSXRhbGljLnBmYg==.png to dataset.
# On image 338.
# Appending Q2VudHVyeSBTY2hvb2xib29rIEl0YWxpYy5wZmI=.png to dataset.
# On image 339.
# Appending Q2VudHVyeSBTY2hvb2xib29rIEl0YWxpYyBCVC50dGY=.png to dataset.
# On image 340.
# Appending Q2VudHVyeSBTY2hvb2xib29rIFNTaSBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 341.
# Appending Q2VudHVyeSBTY2hvb2xib29rIFQgRUUgUmVndWxhciBJdGFsaWMucGZi.png to dataset.
# On image 342.
# Appending Q2VudHVyeTcyNSBCbGsgQlQgQmxhY2sudHRm.png to dataset.
# On image 343.
# Appending Q2VudHVyeTcyNSBCZENuIEJUIEJvbGQudHRm.png to dataset.
# On image 344.
# Appending Q2VudHVyeTcyNUJULUl0YWxpYy5vdGY=.png to dataset.
# On image 345.
# Appending Q2VudHVyeTcyNUJULVJvbWFuQ29uZGVuc2VkLm90Zg==.png to dataset.
# On image 346.
# Appending Q2VudHVyeTczMSBCVCBJdGFsaWMudHRm.png to dataset.
# On image 347.
# Appending Q2VudHVyeTczMUJULUJvbGRJdGFsaWNBLm90Zg==.png to dataset.
# On image 348.
# Appending Q2VudHVyeU9sZFN0eWxlU3RkLVJlZ3VsYXIub3Rm.png to dataset.
# On image 349.
# Appending Q2VudHVyeU9TTVRTdGQtQm9sZEl0YWxpYy5vdGY=.png to dataset.
# On image 350.
# Appending Q2VudHVyeU9TTVRTdGQtSXRhbGljLm90Zg==.png to dataset.
# On image 351.
# Appending Q2VudHVyeUlUQ0JRLUJvb2tJdGFsaWMub3Rm.png to dataset.
# On image 352.
# Appending Q2VudHVyeUlUQ0JRLUxpZ2h0Lm90Zg==.png to dataset.
# On image 353.
# Appending Q2VudHVyeUlUQ0NvbmRlbnNlZEJRLUJvb2sub3Rm.png to dataset.
# On image 354.
# Appending Q2VudHVyeUlUQ0NvbmRlbnNlZEJRLUJvbGQub3Rm.png to dataset.
# On image 355.
# Appending Q2VudHVyeUlUQ0NvbmRlbnNlZEJRLUxpZ2h0Lm90Zg==.png to dataset.
# On image 356.
# Appending Q2VudHVyeUlUQ2J5QlQtQm9sZENvbmRJdGFsaWMub3Rm.png to dataset.
# On image 357.
# Appending Q2VudHVyeUlUQ2J5QlQtQm9sZENvbmRlbnNlZC5vdGY=.png to dataset.
# On image 358.
# Appending Q2VudHVyeUlUQ2J5QlQtTGlnaHRDb25kSXRhbGljLm90Zg==.png to dataset.
# On image 359.
# Appending Q2VudHVyeUNvbmRCb29rSXRhbGljLm90Zg==.png to dataset.
# On image 360.
# Appending Q2VudHVyeVN0ZC1VbHRyYUl0YWxpYy5vdGY=.png to dataset.
# On image 361.
# Appending Q2VudHVyeVNjaG9vbC5vdGY=.png to dataset.
# On image 362.
# Appending Q2VudHVyeVNjaG9vbGJvb2tCVC1Sb21hbi5vdGY=.png to dataset.
# On image 363.
# Appending Q2VudHVyeVNjaG9vbGJvb2tFRi1Cb2wub3Rm.png to dataset.
# On image 364.
# Appending Q2VyaWdvRUYtQm9sZEl0YWxpYy5vdGY=.png to dataset.
# On image 365.
# Appending Q2xhaXJ2YXV4TFRTdGQub3Rm.png to dataset.
# On image 366.
# Appending Q2xhc3NpY2EgT25lLnR0Zg==.png to dataset.
# On image 367.
# Appending Q2xhc3NpY2EtSXRhbGljLnR0Zg==.png to dataset.
# On image 368.
# Appending Q2xhc3NpY2FsR2FyYW1vbmRCVC1Sb21hbi5vdGY=.png to dataset.
# On image 369.
# Appending Q2xhc3NpYyBUcmFzaCAxIEJSSy50dGY=.png to dataset.
# On image 370.
# Appending Q2xhc3NpYzEwNjUudHRm.png to dataset.
# On image 371.
# Appending Q2xhcml0eSBHb3RoaWMgU0YudHRm.png to dataset.
# On image 372.
# Appending Q2xhcmVuZG9uIEh2IEJUIEhlYXZ5LnR0Zg==.png to dataset.
# On image 373.
# Appending Q2xhcmVuZG9uIEJsYWNrLnBmYg==.png to dataset.
# On image 374.
# Appending Q2xhcmVuZG9uQlEtQmxhY2sub3Rm.png to dataset.
# On image 375.
# Appending Q2xhcmVuZG9uTVRTdGQub3Rm.png to dataset.
# On image 376.
# Appending Q2xlb3BhdHJhLm90Zg==.png to dataset.
# On image 377.
# Appending Q2xlcmljIEJsYWNrIFNTaSBCbGFjayBJdGFsaWMudHRm.png to dataset.
# On image 378.
# Appending Q2xlcmZhY2UtQm9sZC5vdGY=.png to dataset.
# On image 379.
# Appending Q2xlcmZhY2UtQm9sZEl0YS5vdGY=.png to dataset.
# On image 380.
# Appending Q2xlcmZhY2UtRGVtaUJvbGQub3Rm.png to dataset.
# On image 381.
# Appending Q2xldmVyIER1a2UgQlROIFNtb290aC50dGY=.png to dataset.
# On image 382.
# Appending Q2xlYXJ2aWV3SHd5LTYtQi50dGY=.png to dataset.
# On image 383.
# Appending Q2xlYXJmYWNlIElUQyBCbGFjay50dGY=.png to dataset.
# On image 384.
# Appending Q2xlYXJmYWNlIElUQyBCbGFjayBJdGFsaWMudHRm.png to dataset.
# On image 385.
# Appending Q2xlYXJmYWNlQVRGQlEtQm9sZC5vdGY=.png to dataset.
# On image 386.
# Appending Q2xlYXJmYWNlR290aGljTFQtQmxhY2sub3Rm.png to dataset.
# On image 387.
# Appending Q2xlYXJmYWNlR290aGljTFRTdGQtTGlnaHQub3Rm.png to dataset.
# On image 388.
# Appending Q2xlYXJmYWNlTFQtSGVhdnkub3Rm.png to dataset.
# On image 389.
# Appending Q2xlYXJmYWNlTVRTdGQtQm9sZC5vdGY=.png to dataset.
# On image 390.
# Appending Q2xlYXJnb3RoaWMtRXh0cmFCb2xkLm90Zg==.png to dataset.
# On image 391.
# Appending Q2xlYXJnb3RoaWMtUmVndWxhckl0YS5vdGY=.png to dataset.
# On image 392.
# Appending Q2xlYXJseSBHb3RoaWMgSGVhdnkgSXRhbGljLnR0Zg==.png to dataset.
# On image 393.
# Appending Q2xpcGUgT3Blbi50dGY=.png to dataset.
# On image 394.
# Appending Q2xpcXVlLVNlcmlmQm9sZE9ibGlxdWUub3Rm.png to dataset.
# On image 395.
# Appending Q2xpY2hlZUNFLU9ibGlxdWUub3Rm.png to dataset.
# On image 396.
# Appending Q2xvaXN0ZXJPcGVuRmFjZSBCVC50dGY=.png to dataset.
# On image 397.
# Appending Q2xvaXN0ZXJTdGQtT3BlbkZhY2Uub3Rm.png to dataset.
# On image 398.
# Appending Q2xvdmVySVRDLm90Zg==.png to dataset.
# On image 399.
# Appending Q2xvY2t3b3JrIFJlZ3VsYXIudHRm.png to dataset.
# On image 400.
# Appending Q3J1bmNoeUZheFBob250Lm90Zg==.png to dataset.
# On image 401.
# Appending Q3J1c3RpRXN0LnR0Zg==.png to dataset.
# On image 402.
# Appending Q3J5c3RhbHNIYW5kIFJlZ3VsYXIudHRm.png to dataset.
# On image 403.
# Appending Q3Jha29vbSEudHRm.png to dataset.
# On image 404.
# Appending Q3JhenkgR2lybHogQmxvbmQgQlROLnR0Zg==.png to dataset.
# On image 405.
# Appending Q3JhY2tkb3duIFIgLUJSSy0udHRm.png to dataset.
# On image 406.
# Appending Q3Jld0N1dENhcHMgSXRhbGljLnR0Zg==.png to dataset.
# On image 407.
# Appending Q3Jpc3RvTGlraWQgVHJ5b3V0LnR0Zg==.png to dataset.
# On image 408.
# Appending Q3JpY2tldC50dGY=.png to dataset.
# On image 409.
# Appending Q3JvaXNzYW50RUYub3Rm.png to dataset.
# On image 410.
# Appending Q3Jvbm9zUHJvLUJvbGRDYXB0SXQub3Rm.png to dataset.
# On image 411.
# Appending Q3Jvbm9zUHJvLUJvbGRTdWJoLm90Zg==.png to dataset.
# On image 412.
# Appending Q3Jvbm9zUHJvLUNhcHRJdC5vdGY=.png to dataset.
# On image 413.
# Appending Q3Jvbm9zUHJvLVJlZ3VsYXIub3Rm.png to dataset.
# On image 414.
# Appending Q3Jvbm9zUHJvLVNlbWlib2xkSXQub3Rm.png to dataset.
# On image 415.
# Appending Q3Jvc2J5c0hhbmQudHRm.png to dataset.
# On image 416.
# Appending Q3Jvc3NvdmVyIEJvbGRPYmxpcXVlLnR0Zg==.png to dataset.
# On image 417.
# Appending Q3Jvc3NvdmVyIEV4dHJhTGlnaHQudHRm.png to dataset.
# On image 418.
# Appending Q3liZXJ3aGl6LnR0Zg==.png to dataset.
# On image 419.
# Appending Q3ljbGluLnR0Zg==.png to dataset.
# On image 420.
# Appending Q3V0dGVyUm9tYW4ub3Rm.png to dataset.
# On image 421.
# Appending Q3VybHpNVFN0ZC1SZWd1bGFyLm90Zg==.png to dataset.
# On image 422.
# Appending Q3VydmF0dXJlLVJvdW5kZWQub3Rm.png to dataset.
# On image 423.
# Appending Q3VydmF0dXJlLVJvdW5kZWRJdGFsaWMub3Rm.png to dataset.
# On image 424.
# Appending Q3VzaGluZ0Jvb2tJdGFsaWMub3Rm.png to dataset.
# On image 425.
# Appending Q3VzaGluZ0l0Y1RFRUhlYS50dGY=.png to dataset.
# On image 426.
# Appending Q3VzaGluZ0VGLUhlYXZ5SXRhbGljLm90Zg==.png to dataset.
# On image 427.
# Appending Q3VzaGluZ1N0ZC1Cb29rSXRhbGljLm90Zg==.png to dataset.
# On image 428.
# Appending Q3VzaGluZyBIZWF2eSBJdGFsaWMgQlQudHRm.png to dataset.
# On image 429.
# Appending QklHQ1NIQUQgTGVmdHkudHRm.png to dataset.
# On image 430.
# Appending QkRmYXplci5vdGY=.png to dataset.
# On image 431.
# Appending QlJFQUtCRUFULm90Zg==.png to dataset.
# On image 432.
# Appending QlZHSGZldHRLdXJzaXYub3Rm.png to dataset.
# On image 433.
# Appending QlZHUGljdEVpbnMub3Rm.png to dataset.
# On image 434.
# Appending Qm90b24gUmVndWxhci50dGY=.png to dataset.
# On image 435.
# Appending Qm90b24tTGlnaHRJdGFsaWMub3Rm.png to dataset.
# On image 436.
# Appending Qm90b25CUS1NZWRpdW1JdGFsaWMub3Rm.png to dataset.
# On image 437.
# Appending Qm91Z2FuIEJsYWNrIFNTaSBCb2xkLnR0Zg==.png to dataset.
# On image 438.
# Appending Qm91Z2FuIEJvb2sgU1NpIEJvb2sudHRm.png to dataset.
# On image 439.
# Appending Qm91Z2FuIFNTaSBTZW1pIEJvbGQudHRm.png to dataset.
# On image 440.
# Appending Qm94c3ByaW5nQS50dGY=.png to dataset.
# On image 441.
# Appending Qm9iYmllc0hhbmQudHRm.png to dataset.
# On image 442.
# Appending Qm9kaWUgTUYgRmxhZy50dGY=.png to dataset.
# On image 443.
# Appending Qm9kb25pIE1UIEl0YWxpYy50dGY=.png to dataset.
# On image 444.
# Appending Qm9kb25pIE9sZCBGYWNlIEJFIE1lZGl1bSBJdGFsaWMgT2xkc3R5bGUgRmlndXJlcy50dGY=.png to dataset.
# On image 445.
# Appending Qm9kb25pIFN2dHlUd28gSVRDIFRUIEJvbGQudHRm.png to dataset.
# On image 446.
# Appending Qm9kb25pIFNpeCBJVEMgVFQgQm9vay50dGY=.png to dataset.
# On image 447.
# Appending Qm9kb25pIFNpeCBPUyBJVEMgVFQgQm9sZC50dGY=.png to dataset.
# On image 448.
# Appending Qm9kb25pIFNTaS50dGY=.png to dataset.
# On image 449.
# Appending Qm9kb25pLUJvbGRJdGFsaWMub3Rm.png to dataset.
# On image 450.
# Appending Qm9kb25pLUl0YWxpYy5vdGY=.png to dataset.
# On image 451.
# Appending Qm9kb25pQ2xhc3NpYy1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 452.
# Appending Qm9kb25pQkUtTWVkaXVtQ24ub3Rm.png to dataset.
# On image 453.
# Appending Qm9kb25pQkUtUmVndWxhci5vdGY=.png to dataset.
# On image 454.
# Appending Qm9kb25pQlQtUm9tYW4ub3Rm.png to dataset.
# On image 455.
# Appending Qm9kb25pQmF1ZXJCUS1SZWd1bGFyLm90Zg==.png to dataset.
# On image 456.
# Appending Qm9kb25pQmVydENvbkJRLUJvbGRJdGFsaWMub3Rm.png to dataset.
# On image 457.
# Appending Qm9kb25pQmVydGhvbGRCUS1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 458.
# Appending Qm9kb25pQy1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 459.
# Appending Qm9kb25pQy1JdGFsaWMub3Rm.png to dataset.
# On image 460.
# Appending Qm9kb25pREJsYS50dGY=.png to dataset.
# On image 461.
# Appending Qm9kb25pRUYtRGVtaUJvbGQub3Rm.png to dataset.
# On image 462.
# Appending Qm9kb25pRUYtRGVtaUJvbGRJdGEub3Rm.png to dataset.
# On image 463.
# Appending Qm9kb25pRUYtTGlnaHQub3Rm.png to dataset.
# On image 464.
# Appending Qm9kb25pSUNHLm90Zg==.png to dataset.
# On image 465.
# Appending Qm9kb25pT2xkRmFjZUJFLVJlZ3VsYXIub3Rm.png to dataset.
# On image 466.
# Appending Qm9kb25pT2xkRmFjZUJRLUl0YWxpYy5vdGY=.png to dataset.
# On image 467.
# Appending Qm9kb25pT2xkRmFjZUJRLVJlZ3VsYXIub3Rm.png to dataset.
# On image 468.
# Appending Qm9kb25pT2xkRmFjZUV4cEJRLU1lZGl1bS5vdGY=.png to dataset.
# On image 469.
# Appending Qm9kb25pTVRTdGQtSXRhbGljLm90Zg==.png to dataset.
# On image 470.
# Appending Qm9kb25pU2l4SVRDLUJvb2tJdGFsT1Mub3Rm.png to dataset.
# On image 471.
# Appending Qm9kb25pU2l4SVRDLUJvbGQub3Rm.png to dataset.
# On image 472.
# Appending Qm9kb25pU2l4SVRDLUJvbGRJdGFsT1Mub3Rm.png to dataset.
# On image 473.
# Appending Qm9kb25pU2l4SVRDU3RkLUJvbGQub3Rm.png to dataset.
# On image 474.
# Appending Qm9kb25pU2V2SVRDLUJvb2tJdGFsLm90Zg==.png to dataset.
# On image 475.
# Appending Qm9kb25pU3RkLUl0YWxpYy5vdGY=.png to dataset.
# On image 476.
# Appending Qm9kb25pVHdlSVRDLUJvbGQub3Rm.png to dataset.
# On image 477.
# Appending Qm9kb3hpLURlbWlCb2xkLm90Zg==.png to dataset.
# On image 478.
# Appending Qm9kZWdhU2VyaWYtTWVkaXVtT2xkc3R5bGUub3Rm.png to dataset.
# On image 479.
# Appending Qm9ndXNmbG93LnR0Zg==.png to dataset.
# On image 480.
# Appending Qm9sZGZhY2VJdGFsaWMtLnR0Zg==.png to dataset.
# On image 481.
# Appending Qm9sZGZhY2VJdGFsaWMtU2VtaUJvbGQtSXRhbGljLnR0Zg==.png to dataset.
# On image 482.
# Appending Qm9uayBPdXRlcmN1dC50dGY=.png to dataset.
# On image 483.
# Appending Qm9uZWhlYWQudHRm.png to dataset.
# On image 484.
# Appending Qm9va21hbiBCVCBJdGFsaWMudHRm.png to dataset.
# On image 485.
# Appending Qm9va21hbiBCVCBSb21hbi50dGY=.png to dataset.
# On image 486.
# Appending Qm9va21hbiBPbGQgU3R5bGUgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 487.
# Appending Qm9va21hbiBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 488.
# Appending Qm9va21hbkJRLURlbWlCb2xkLm90Zg==.png to dataset.
# On image 489.
# Appending Qm9va21hbkJRLURlbWlCb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 490.
# Appending Qm9va21hbklUQ1N0ZC1MaWdodEl0YWxpYy5vdGY=.png to dataset.
# On image 491.
# Appending Qm9va21hblN0ZC1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 492.
# Appending Qm9va2VyLm90Zg==.png to dataset.
# On image 493.
# Appending Qm9vemxlIERpc3BsYXkgU1NpIEl0YWxpYy50dGY=.png to dataset.
# On image 494.
# Appending Qm9yb3dheUJPbGQudHRm.png to dataset.
# On image 495.
# Appending Qm9yem9pIE1lZGl1bS50dGY=.png to dataset.
# On image 496.
# Appending Qm9yZGVhdXggSUNHLnR0Zg==.png to dataset.
# On image 497.
# Appending Qm9yZGVhdXggSXRhbGljIFBsYWluLnR0Zg==.png to dataset.
# On image 498.
# Appending Qm9yZGVhdXhNZWRpdW0ub3Rm.png to dataset.
# On image 499.
# Appending Qm9yZGVsbG8tU2hhZGVkLm90Zg==.png to dataset.
# On image 500.
# Appending Qm9zbmlhIEQgQm9sZC50dGY=.png to dataset.
# On image 501.
# Appending Qm9zdG9uIFRyYWZmaWMudHRm.png to dataset.
# On image 502.
# Appending QmF0aCBMaWdodEl0YWxpYy50dGY=.png to dataset.
# On image 503.
# Appending QmF0YWtDb25kZW5zZWRJVENTdGRCb2xkLm90Zg==.png to dataset.
# On image 504.
# Appending QmF1aGF1c0l0Y1RFRU1lZC50dGY=.png to dataset.
# On image 505.
# Appending QmF1aGF1c0l0Y1RFRUJvbC50dGY=.png to dataset.
# On image 506.
# Appending QmF1aGF1c0lUQ2J5QlQtTGlnaHQub3Rm.png to dataset.
# On image 507.
# Appending QmF1aGF1cy1EZW1pLm90Zg==.png to dataset.
# On image 508.
# Appending QmF1aGF1cyBCb2xkLnR0Zg==.png to dataset.
# On image 509.
# Appending QmF1ZXIgQm9kb25pIEJvbGQgQ29uZGVuc2VkIEJULnR0Zg==.png to dataset.
# On image 510.
# Appending QmF1ZXJCb2RvbmlCVC1CbGFjay5vdGY=.png to dataset.
# On image 511.
# Appending QmF1ZXJCb2RvbmlCVC1UaXRsaW5nLm90Zg==.png to dataset.
# On image 512.
# Appending QmF1ZXJUb3BpYy1CbGQub3Rm.png to dataset.
# On image 513.
# Appending QmF5ZXJFeHBlcmltZW50LnR0Zg==.png to dataset.
# On image 514.
# Appending QmFieSBLcnVmZnkudHRm.png to dataset.
# On image 515.
# Appending QmFja3RhbGtTZXJpZiBCVE4gU0MgQm9sZE9ibGlxdWUudHRm.png to dataset.
# On image 516.
# Appending QmFjY2FyYXRXaWRlIFJlZ3VsYXIudHRm.png to dataset.
# On image 517.
# Appending QmFjY3VzIFJlZ3VsYXIudHRm.png to dataset.
# On image 518.
# Appending QmFkIE1vZm8udHRm.png to dataset.
# On image 519.
# Appending QmFkLnR0Zg==.png to dataset.
# On image 520.
# Appending QmFpbGV5IFNhbnMgSVRDIEJvb2sudHRm.png to dataset.
# On image 521.
# Appending QmFpbGV5U2Fuc0lUQ1N0ZC1Cb2xkLm90Zg==.png to dataset.
# On image 522.
# Appending QmFrZXIgU2lnbmV0IEJULnR0Zg==.png to dataset.
# On image 523.
# Appending QmFrZXJTaWduZXQgQlQgUm9tYW4udHRm.png to dataset.
# On image 524.
# Appending QmFsbGFudGluZXMtRGVtaUJvbGQub3Rm.png to dataset.
# On image 525.
# Appending QmFsbGFudGluZXNTY3JpcHRFRi1NZWRpdW0ub3Rm.png to dataset.
# On image 526.
# Appending QmFsc2Ftby50dGY=.png to dataset.
# On image 527.
# Appending QmFsdHJhR0Qub3Rm.png to dataset.
# On image 528.
# Appending QmFsYUN5bnd5ZC50dGY=.png to dataset.
# On image 529.
# Appending QmFsYW5jZS1MaWdodC5vdGY=.png to dataset.
# On image 530.
# Appending QmFsYW5jZS1MaWdodENhcHNJdGFsaWMub3Rm.png to dataset.
# On image 531.
# Appending QmFsYW5jZUxpZ2h0LUl0YWxpYy5vdGY=.png to dataset.
# On image 532.
# Appending QmFsYW5jZUxpZ2h0LUNhcHMub3Rm.png to dataset.
# On image 533.
# Appending QmFubmVyU3RkLm90Zg==.png to dataset.
# On image 534.
# Appending QmFuY29JVENTdGQtSGVhdnkub3Rm.png to dataset.
# On image 535.
# Appending QmFuY29JVENTdGQtTGlnaHQub3Rm.png to dataset.
# On image 536.
# Appending QmFuZ2xlIENvbmRlbnNlZCBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 537.
# Appending QmFycnlzSGFuZCBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 538.
# Appending QmFydCBIZWF2eSBJdGFsaWMudHRm.png to dataset.
# On image 539.
# Appending QmFydCBIZWF2eSBOb3JtYWwudHRm.png to dataset.
# On image 540.
# Appending QmFydCBJdGFsaWMudHRm.png to dataset.
# On image 541.
# Appending QmFydCBUaGluIEhlYXZ5IEJvbGQudHRm.png to dataset.
# On image 542.
# Appending QmFydCBUaGluIEJvbGRJdGFsaWMudHRm.png to dataset.
# On image 543.
# Appending QmFyY29vbC50dGY=.png to dataset.
# On image 544.
# Appending QmFyY2Vsb25hIEJvbGQudHRm.png to dataset.
# On image 545.
# Appending QmFyY2Vsb25hSVRDU3RkLUJvb2tJdGFsaWMub3Rm.png to dataset.
# On image 546.
# Appending QmFyY2Vsb25hSVRDU3RkLUJvbGQub3Rm.png to dataset.
# On image 547.
# Appending QmFyY2xheSBPcGVuLnR0Zg==.png to dataset.
# On image 548.
# Appending QmFyYmVyUG9sZSBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 549.
# Appending QmFza2VydmlsbGUgQm9sZCBJdCBXaW45NUJUKDEpLnR0Zg==.png to dataset.
# On image 550.
# Appending QmFza2VydmlsbGUgQmxhY2sgU1NpIEJvbGQgSXRhbGljLnR0Zg==.png to dataset.
# On image 551.
# Appending QmFza2VydmlsbGUgU1NpLnR0Zg==.png to dataset.
# On image 552.
# Appending QmFza2VydmlsbGUtTm9ybWFsLUl0YWxpYy50dGY=.png to dataset.
# On image 553.
# Appending QmFza2VydmlsbGVCUS1JdGFsaWMub3Rm.png to dataset.
# On image 554.
# Appending QmFza2VydmlsbGVCUS1NZWRpdW0ub3Rm.png to dataset.
# On image 555.
# Appending QmFza2VydmlsbGVCVC1Sb21hbi5vdGY=.png to dataset.
# On image 556.
# Appending QmFza2VydmlsbGVFRi1NZWRpdW0ub3Rm.png to dataset.
# On image 557.
# Appending QmFza2VydmlsbGVOZXdCUS1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 558.
# Appending QmFza2VydmlsbGVULnR0Zg==.png to dataset.
# On image 559.
# Appending QmFza2VydmlsbGVULVJlZ3Uub3Rm.png to dataset.
# On image 560.
# Appending QmFza2VydmlsbGVULVJlZ3VJdGFsLm90Zg==.png to dataset.
# On image 561.
# Appending QmFza2VydmxsZTIgQlQgUm9tYW4udHRm.png to dataset.
# On image 562.
# Appending QmFzaWMgU2FucyBIZWF2eSBTRiBCb2xkLnR0Zg==.png to dataset.
# On image 563.
# Appending QmFzaWMgU2FucyBTRiBCb2xkLnR0Zg==.png to dataset.
# On image 564.
# Appending QmFzc2V0dCBUaGluIEJvbGRJdGFsaWMudHRm.png to dataset.
# On image 565.
# Appending QmFzcXVlIFRoaW4gTm9ybWFsLnR0Zg==.png to dataset.
# On image 566.
# Appending QmFzZU1vbm9XaWRlVGhpbiBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 567.
# Appending QmFzZU5pbmUgQm9sZC50dGY=.png to dataset.
# On image 568.
# Appending QmFzZU5pbmVCSS50dGY=.png to dataset.
# On image 569.
# Appending QmFzZU5pbmVTbWFsbENhcHMgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 570.
# Appending QmFzZU5pbmVTQ0IudHRm.png to dataset.
# On image 571.
# Appending QmFzZVR3ZWx2ZVNlcmlmU0NCLnR0Zg==.png to dataset.
# On image 572.
# Appending Qml0c3RyZWFtIEFtZXJpZ28gQm9sZC5wZmI=.png to dataset.
# On image 573.
# Appending Qml0c3RyZWFtIEFtZXJpZ28gQm9sZCBJdGFsaWMucGZi.png to dataset.
# On image 574.
# Appending Qml0c3RyZWFtIEFycnVzIEJsYWNrLnBmYg==.png to dataset.
# On image 575.
# Appending Qml0c3RyZWFtIElvd2FuIE9sZCBTdHlsZS5wZmI=.png to dataset.
# On image 576.
# Appending Qml0c3RyZWFtIENoYXJ0ZXIgQmxhY2sgSXRhbGljIE9TRi5wZmI=.png to dataset.
# On image 577.
# Appending Qml0c3RyZWFtIENvb3BlciBMaWdodCBJdGFsaWMucGZi.png to dataset.
# On image 578.
# Appending Qml0c3RyZWFtIFZlcmEgU2FucyBNb25vIE9ibGlxdWUudHRm.png to dataset.
# On image 579.
# Appending Qml0c3RyZWFtIFZlcmEgU2VyaWYgQm9sZC50dGY=.png to dataset.
# On image 580.
# Appending Qml0d2lzZS50dGY=.png to dataset.
# On image 581.
# Appending Qml4bGVlLUhlYXZ5LnR0Zg==.png to dataset.
# On image 582.
# Appending Qml4bGVlQ25kLUhlYXZ5LnR0Zg==.png to dataset.
# On image 583.
# Appending Qmlja2hhbSBTY3JpcHQgVHdvLnR0Zg==.png to dataset.
# On image 584.
# Appending QmlndG93bmVCb2xkLnR0Zg==.png to dataset.
# On image 585.
# Appending QmlnIEJhY29uIFRyeW91dC50dGY=.png to dataset.
# On image 586.
# Appending Qmlqb3V4LUJvbGQub3Rm.png to dataset.
# On image 587.
# Appending QmlraW5pLnR0Zg==.png to dataset.
# On image 588.
# Appending QmlsbGJvYXJkIDExIENvbmRlbnNlZCBOb3JtYWwudHRm.png to dataset.
# On image 589.
# Appending QmlsbHV5LnR0Zg==.png to dataset.
# On image 590.
# Appending QmlsYm9EaXNwbGF5IEJvbGQgSXRhbGljLnR0Zg==.png to dataset.
# On image 591.
# Appending QmlubmVyRC50dGY=.png to dataset.
# On image 592.
# Appending QmluZ28ub3Rm.png to dataset.
# On image 593.
# Appending QmlvbmljIENvbWljIEV4cCBJdGFsaWMudHRm.png to dataset.
# On image 594.
# Appending QmlvbmljIFR5cGUgQ29uZGVuc2VkLnR0Zg==.png to dataset.
# On image 595.
# Appending QmlvbWVjaGFuaWMudHRm.png to dataset.
# On image 596.
# Appending QmlyZC50dGY=.png to dataset.
# On image 597.
# Appending QmV0b25FRi1FeHRyYUJvbGQub3Rm.png to dataset.
# On image 598.
# Appending QmV0dGVyIE9mZiAxLnR0Zg==.png to dataset.
# On image 599.
# Appending QmV0dGVyS2FtcCBCb2xkSXRhbGljLnR0Zg==.png to dataset.
# On image 600.
# Appending QmV0dGVySW5ncmlhbmEgSXRhbGljLnR0Zg==.png to dataset.
# On image 601.
# Appending QmV0dGVyVHlwZVJpZ2h0IEJvbGRJdGFsaWMudHRm.png to dataset.
# On image 602.
# Appending QmV0YSBCbG9jay50dGY=.png to dataset.
# On image 603.
# Appending QmV0YVNlbWktQm9sZC5vdGY=.png to dataset.
# On image 604.
# Appending QmV0YWNhcGl0YWwudHRm.png to dataset.
# On image 605.
# Appending QmVhbSBSaWRlciBFeHBhbmRlZC50dGY=.png to dataset.
# On image 606.
# Appending QmVhc3QudHRm.png to dataset.
# On image 607.
# Appending QmVhckJ1dHRlVCBQbGFpbi50dGY=.png to dataset.
# On image 608.
# Appending QmVhdG5pa0hheXNlZWQudHRm.png to dataset.
# On image 609.
# Appending QmVhdSBUaGluIEl0YWxpYy50dGY=.png to dataset.
# On image 610.
# Appending QmVhdXJlZ2FyZCBEaXNwbGF5IFNTaS50dGY=.png to dataset.
# On image 611.
# Appending QmVhY2ggVGhpbiBCb2xkLnR0Zg==.png to dataset.
# On image 612.
# Appending QmVjY2FyaWEudHRm.png to dataset.
# On image 613.
# Appending QmVla21hbi1TcXVhcmVCb2xkLm90Zg==.png to dataset.
# On image 614.
# Appending QmVla21hbi1TcXVhcmVSZWd1bGFyLm90Zg==.png to dataset.
# On image 615.
# Appending QmVlc2tuZWVzIFNDIElUQyBUVC50dGY=.png to dataset.
# On image 616.
# Appending QmVlc2tuZWVzQy5vdGY=.png to dataset.
# On image 617.
# Appending QmVldGhhbS1MaWdodC5vdGY=.png to dataset.
# On image 618.
# Appending QmVsaXppb0JvbGQub3Rm.png to dataset.
# On image 619.
# Appending QmVsbEdvdGhpY1N0ZC1CbGFjay5vdGY=.png to dataset.
# On image 620.
# Appending QmVsbENlbnQgU3ViQ2FwIEJUIFN1Yi1DYXB0aW9uLnR0Zg==.png to dataset.
# On image 621.
# Appending QmVsbENlbnRlbm5pYWwtTmFtZUFuZE51bWJlci5vdGY=.png to dataset.
# On image 622.
# Appending QmVsbGFteUV4dHJhQm9sZC5vdGY=.png to dataset.
# On image 623.
# Appending QmVsbGhvcE5GLnR0Zg==.png to dataset.
# On image 624.
# Appending QmVsd2VFRi1Cb2xkLm90Zg==.png to dataset.
# On image 625.
# Appending QmVsd2VFRi1Cb2xkQ29uZGVuc2VkLm90Zg==.png to dataset.
# On image 626.
# Appending QmVsd2VTdGQtTGlnaHRJdGFsaWMub3Rm.png to dataset.
# On image 627.
# Appending QmVsdWNpYW4tRGVtaUJvbGQub3Rm.png to dataset.
# On image 628.
# Appending QmVtYm8gTU9OT1RZUEUgRXhwZXJ0IEJvbGQgT3NGLnR0Zg==.png to dataset.
# On image 629.
# Appending QmVtYm8tU0Mub3Rm.png to dataset.
# On image 630.
# Appending QmVtYm9JbmZhbnRNVFN0ZC1Cb2xkSXQub3Rm.png to dataset.
# On image 631.
# Appending QmVtYm9UaXRsaW5nTVRTdGQub3Rm.png to dataset.
# On image 632.
# Appending QmVuZ3VpYXQgRnJpc2t5IEFUVC50dGY=.png to dataset.
# On image 633.
# Appending QmVuZ3VpYXRCUS1NZWRpdW0ub3Rm.png to dataset.
# On image 634.
# Appending QmVuZ3VpYXRDb25kZW5zZWRCUS1Cb29rSXRhbGljLm90Zg==.png to dataset.
# On image 635.
# Appending QmVuZ3VpYXRDb25kZW5zZWRCUS1NZWRpdW0ub3Rm.png to dataset.
# On image 636.
# Appending QmVuZ3VpYXRFRi1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 637.
# Appending QmVuZ3VpYXRHb3RoaWMtTWVkaXVtLm90Zg==.png to dataset.
# On image 638.
# Appending QmVuZ3VpYXRHb3RoaWNCUS1Cb2xkSXRhbGljLm90Zg==.png to dataset.
# On image 639.
# Appending QmVuZ3VpYXRHb3RoaWNCUS1NZWRpdW0ub3Rm.png to dataset.
# On image 640.
# Appending QmVuZ3VpYXRHb3RoaWNMVC1IZWF2eS5vdGY=.png to dataset.
# On image 641.
# Appending QmVuZ3VpYXRHb3RoaWNTdGQtTWVkaXVtLm90Zg==.png to dataset.
# On image 642.
# Appending QmVuZ3VpYXRJdGNURUUgQm9sZCBJdGFsaWMudHRm.png to dataset.
# On image 643.
# Appending QmVuZ3VpYXRJVENieUJULUJvb2tDb25kZW5zZWQub3Rm.png to dataset.
# On image 644.
# Appending QmVya2VsZXkgT2xkc3R5bGUgSXRhbGljLnR0Zg==.png to dataset.
# On image 645.
# Appending QmVya2VsZXlPbGRTdHlsZUVGLUJvbGRJdGFsaWMub3Rm.png to dataset.
# On image 646.
# Appending QmVya2VsZXlPbGRzdHlsZUJvbGQub3Rm.png to dataset.
# On image 647.
# Appending QmVya2VsZXlPbGRzdHlsZUlUQ2J5QlQtTWVkSXRhbC5vdGY=.png to dataset.
# On image 648.
# Appending QmVya2VsZXlTdGQtQm9vay5vdGY=.png to dataset.
# On image 649.
# Appending QmVybGluc2Fucy1Cb2xkRXhwZXJ0Lm90Zg==.png to dataset.
# On image 650.
# Appending QmVybGluIFNhbnMgRkIudHRm.png to dataset.
# On image 651.
# Appending QmVybGluU21hbGxDYXBzLnR0Zg==.png to dataset.
# On image 652.
# Appending QmVybGluZ0JRLVJlZ3VsYXIub3Rm.png to dataset.
# On image 653.
# Appending QmVybGluZ0JRLVNlbWlCb2xkLm90Zg==.png to dataset.
# On image 654.
# Appending QmVybGluZ0VGLVJlZ3VsYXIub3Rm.png to dataset.
# On image 655.
# Appending QmVybGluZXIgR3JvdGVzayBNZWRpdW0udHRm.png to dataset.
# On image 656.
# Appending QmVybGluZXJHcm90ZXNrLUxpZ2h0Lm90Zg==.png to dataset.
# On image 657.
# Appending QmVybmhhcmQgTW9kZXJuIEJULnR0Zg==.png to dataset.
# On image 658.
# Appending QmVybmhhcmQgTW9kZXJuIEJvbGQgSXRhbGljIEJULnR0Zg==.png to dataset.
# On image 659.
# Appending QmVybmhhcmRGYXNoaW9uIEJULnR0Zg==.png to dataset.
# On image 660.
# Appending QmVybmhhcmRNb2Rlcm5CUS1JdGFsaWMub3Rm.png to dataset.
# On image 661.
# Appending QmVybnlLbGluZ29uLnR0Zg==.png to dataset.
# On image 662.
# Appending QmVybnN0ZWluLURlbWlCb2xkLm90Zg==.png to dataset.
# On image 663.
# Appending QmVydGhhbS50dGY=.png to dataset.
# ...
# On image 1656.
# Appending RXhjYWxpYnVyIExvZ290eXBlIE5vcm1hbC50dGY=.png to dataset.
# On image 1657.
# Appending RXhjZWxzaW9yLm90Zg==.png to dataset.
# On image 1658.
# Appending RXhlcnQtQmxhY2tJdGFsaWMub3Rm.png to dataset.
# On image 1659.
# Appending RXhpdCBmb250IChmb3IgYSBmaWxtKS50dGY=.png to dataset.
# On image 1660.
# Appending RXhpdCBmb250IGZvciBhIGZpbG0udHRm.png to dataset.
# On image 1661.
# Appending RXhvdGljLUJvbGQgV2QudHRm.png to dataset.
# On image 1662.
# Appending RXhvdGljLURlbWkgQ24gSXRhbGljLnR0Zg==.png to dataset.
# On image 1663.
# Appending RXhvdGMzNTAgRG1CZCBCVCBEZW1pLUJvbGQudHRm.png to dataset.
# On image 1664.
# Appending RXhwb3NlIFdpZGUgTm9ybWFsLnR0Zg==.png to dataset.
# On image 1665.
# Appending RXhwb3NlIFRoaW4gQ29uZGVuc2VkIEJvbGRJdGFsaWMudHRm.png to dataset.
# On image 1666.
# Appending RXhwb3NpdGlvbiBCbGFjayBTU2kgQmxhY2sgSXRhbGljLnR0Zg==.png to dataset.
# On image 1667.
# Appending RXhwcmVzc2FFRi1EZW1pQm9sZC5vdGY=.png to dataset.
# On image 1668.
# Appending RXhwcmVzcyBEZWNvIEdvdGhpYyBTU2kudHRm.png to dataset.
# On image 1669.
# Appending RXJhc0JRLUJvb2sub3Rm.png to dataset.
# On image 1670.
# Appending RXJhc0JRLUxpZ2h0Lm90Zg==.png to dataset.
# On image 1671.
# Appending RXJhc0lUQ2J5QlQtRGVtaS5vdGY=.png to dataset.
# On image 1672.
# Appending RXJhc0VGLUJvbGQub3Rm.png to dataset.
# On image 1673.
# Appending RXJhc2VyRHVzdCBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 1674.
# Appending RXJhcyBCb29rIEJULnR0Zg==.png to dataset.
# On image 1675.
# Appending RXJhcyBCbGFjayBTZW1pQm9sZC50dGY=.png to dataset.
# On image 1676.
# Appending RXJhcyBJdGMgVCBFRSBMaWdodC5wZmI=.png to dataset.
# On image 1677.
# Appending RXJhcyBJdGMgVCBFRSBNZWRpdW0ucGZi.png to dataset.
# On image 1678.
# Appending RXJhcyBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 1679.
# Appending RXJhcyBVbHRyYSBCVC50dGY=.png to dataset.
# On image 1680.
# Appending RXJlaHdvblJvbWFuTkYudHRm.png to dataset.
# On image 1681.
# Appending RXJpY2FzSGFuZCBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 1682.
# Appending RXJpY3NIYW5kIFJlZ3VsYXIudHRm.png to dataset.
# On image 1683.
# Appending RXJpYyBCbGFjay50dGY=.png to dataset.
# On image 1684.
# Appending RXJpYyBMaXRlIEV4dGVuZGVkIEJvbGRJdGFsaWMudHRm.png to dataset.
# On image 1685.
# Appending RXllIGdsYXNzIENvbmRlbnNlZCBOb3JtYWwudHRm.png to dataset.
# On image 1686.
# Appending RXllIGdsYXNzIEV4dGVuZGVkIEl0YWxpYy50dGY=.png to dataset.
# On image 1687.
# Appending RXllIGdsYXNzIFdpZGUgSXRhbGljLnR0Zg==.png to dataset.
# On image 1688.
# Appending RXllIGdsYXNzIFRoaW4gSXRhbGljLnR0Zg==.png to dataset.
# On image 1689.
# Appending RXllY2hhcnQgUmVndWxhci50dGY=.png to dataset.
# On image 1690.
# Appending RXNwcml0IEl0YWxpYy50dGY=.png to dataset.
# On image 1691.
# Appending RXNwcml0RUYtTWVkaXVtSXRhbGljLm90Zg==.png to dataset.
# On image 1692.
# Appending RXNwcml0U0NFRi1Cb29rLm90Zg==.png to dataset.
# On image 1693.
# Appending RXRjZXRlcmEudHRm.png to dataset.
# On image 1694.
# Appending RXRobm9jZW50cmljLnR0Zg==.png to dataset.
# On image 1695.
# Appending RXVudXZlcnNlLUl0YWxpYy5vdGY=.png to dataset.
# On image 1696.
# Appending RXVwaG9yaWMgM0QgQlJLLnR0Zg==.png to dataset.
# On image 1697.
# Appending RXVyb1RlY2huaWNPdXRsaW5lLm90Zg==.png to dataset.
# On image 1698.
# Appending RXVyb3BhLnR0Zg==.png to dataset.
# On image 1699.
# Appending RXVyb3BlRXh0LUJvbGQub3Rm.png to dataset.
# On image 1700.
# Appending RXVyb3N0aWxlLVJvbWFuLURUQy50dGY=.png to dataset.
# On image 1701.
# Appending RXVyb3N0aWxlTFRTdGQtRGVtaU9ibGlxdWUub3Rm.png to dataset.
# On image 1702.
# Appending RXVyb3N0aWxlVEJsYS50dGY=.png to dataset.
# On image 1703.
# Appending RXVyYXNpYSBCb2xkLnR0Zg==.png to dataset.
# On image 1704.
# Appending RXVyYXNpYSBDb25kZW5zZWQgQm9sZEl0YWxpYy50dGY=.png to dataset.
# On image 1705.
# Appending RXVyZWthLU1lZGl1bS5vdGY=.png to dataset.
# On image 1706.
# Appending RXZhbmdlbGljQm9sZC5vdGY=.png to dataset.
# On image 1707.
# Appending RXZlcmx5c0hhbmQgUmVndWxhci50dGY=.png to dataset.
# On image 1708.
# Appending RXZvQlEtTWVkaXVtSXRhbGljLm90Zg==.png to dataset.
# On image 1709.
# Appending SE1hbi50dGY=.png to dataset.
# On image 1710.
# Appending SE9VU0UzMDA5LVNwYWNlYWdlLUJsYWNrLUJldGEucGZi.png to dataset.
# On image 1711.
# Appending SElBSVJQT1JUREVQQVJUVVJFLnR0Zg==.png to dataset.
# On image 1712.
# Appending SElMT0dJTkNPTi50dGY=.png to dataset.
# On image 1713.
# Appending SG91bmRzIEJvbGQudHRm.png to dataset.
# On image 1714.
# Appending SG91c2VHb3RoaWNIRzIzVGV4dC1Cb2xkLm90Zg==.png to dataset.
# On image 1715.
# Appending SG91c2VHb3RoaWNIRzIzVGV4dC1MaWdodC5vdGY=.png to dataset.
# On image 1716.
# Appending SG91c2VNb3ZlbWVudHMtU2lnbi5vdGY=.png to dataset.
# On image 1717.
# Appending SG91c2VNb3ZlbWVudHMtUG9zdGVyLm90Zg==.png to dataset.
# On image 1718.
# Appending SG9ib2tlbi1NZWRpdW0ub3Rm.png to dataset.
# On image 1719.
# Appending SG9iby1UaGluLnR0Zg==.png to dataset.
# On image 1720.
# Appending SG9iYml0IFNGLnR0Zg==.png to dataset.
# On image 1721.
# Appending SG9iYnkgV2lkZSBOb3JtYWwudHRm.png to dataset.
# On image 1722.
# Appending SG9lZmxlclRleHQtUm9tYW4tU21hbGxDYXBzLm90Zg==.png to dataset.
# On image 1723.
# Appending SG9nd2FydHNXaXphcmQudHRm.png to dataset.
# On image 1724.
# Appending SG9nYXJ0aFNjckQudHRm.png to dataset.
# On image 1725.
# Appending SG9saWRheS1JbmRpYS50dGY=.png to dataset.
# On image 1726.
# Appending SG9saWRheSBTcHJpbmdzIEJUTi50dGY=.png to dataset.
# On image 1727.
# Appending SG9saWVyLm90Zg==.png to dataset.
# On image 1728.
# Appending SG9sbHl3b29kIEl0YWxpYy50dGY=.png to dataset.
# On image 1729.
# Appending SG9sbWVzMDAxLnR0Zg==.png to dataset.
# On image 1730.
# Appending SG9tZW1hZGUgUm9ib3QgRXhwYW5kZWQudHRm.png to dataset.
# On image 1731.
# Appending SG9uZGEgUmVndWxhci50dGY=.png to dataset.
# On image 1732.
# Appending SG9uZGFGb250Lm90Zg==.png to dataset.
# On image 1733.
# Appending SG9uZXkgSSBTdG9sZSBZb3VyIEp1bXBlci50dGY=.png to dataset.
# On image 1734.
# Appending SG9uZXlib21iLnR0Zg==.png to dataset.
# On image 1735.
# Appending SG9vZ2UwNDY2LnR0Zg==.png to dataset.
# On image 1736.
# Appending SG9ybGV5IE9TIE1UIEl0YWxpYy50dGY=.png to dataset.
# On image 1737.
# Appending SG9ybGV5T2xkU3R5bGVNVFN0ZC1TYi5vdGY=.png to dataset.
# On image 1738.
# Appending SG9ybnB5cGVJVENTdGQub3Rm.png to dataset.
# On image 1739.
# Appending SG9yc2hhbS1IZWF2eS5vdGY=.png to dataset.
# On image 1740.
# Appending SG9ycmVuZG91cy50dGY=.png to dataset.
# On image 1741.
# Appending SGF3dGhvcm5FRi5vdGY=.png to dataset.
# On image 1742.
# Appending SGFjayAmIFNsYXNoIEJSSy50dGY=.png to dataset.
# On image 1743.
# Appending SGFsbG1hcmtlIEJvbGQgSXRhbGljLnR0Zg==.png to dataset.
# On image 1744.
# Appending SGFsbG1hcmtlIEJvbGQudHRm.png to dataset.
# On image 1745.
# Appending SGFsbG93ZWVuIE1hdGNoLnR0Zg==.png to dataset.
# On image 1746.
# Appending SGFsbG9kb2xseS5vdGY=.png to dataset.
# On image 1747.
# Appending SGFsYnN0YXJrZSBQaWNhLnR0Zg==.png to dataset.
# On image 1748.
# Appending SGFsZkxpZmUudHRm.png to dataset.
# On image 1749.
# Appending SGFtbWVyZWQudHRm.png to dataset.
# On image 1750.
# Appending SGFtYnVyZ2VyLnR0Zg==.png to dataset.
# On image 1751.
# Appending SGFtYnVyZy1EZW1pQm9sZC5vdGY=.png to dataset.
# On image 1752.
# Appending SGFtYnVyZy1NZWRpdW0ub3Rm.png to dataset.
# On image 1753.
# Appending SGFuemVsIENvbmRlbnNlZCBCb2xkIEl0YWxpYy50dGY=.png to dataset.
# On image 1754.
# Appending SGFuIFNvbG8gRXhwIFNoYWRvd0xhc2VyLnR0Zg==.png to dataset.
# On image 1755.
# Appending SGFuIFNvbG8gRXhwYW5kZWQudHRm.png to dataset.
# On image 1756.
# Appending SGFuIFNvbG8gTGFzZXIudHRm.png to dataset.
# On image 1757.
# Appending SGFuIFNvbG8gUHJvLnR0Zg==.png to dataset.
# On image 1758.
# Appending SGFuIFNvbG8udHRm.png to dataset.
# On image 1759.
# Appending SGFuZGljYXAub3Rm.png to dataset.
# On image 1760.
# Appending SGFuZGVsR290RC1MaWdoLm90Zg==.png to dataset.
# On image 1761.
# Appending SGFuZGVsR290T25sU2hhRC1MaWdoLm90Zg==.png to dataset.
# On image 1762.
# Appending SGFuZHdlcmsudHRm.png to dataset.
# On image 1763.
# Appending SGFuZHdyaXRlIFJlZ3VsYXIudHRm.png to dataset.
# On image 1764.
# Appending SGFwcHkgRGF5cyBVcHJpZ2h0LnR0Zg==.png to dataset.
# On image 1765.
# Appending SGFycG9vbi50dGY=.png to dataset.
# On image 1766.
# Appending SGFyZFRpbWVzUmVndWxhci5vdGY=.png to dataset.
# On image 1767.
# Appending SGFyZHkudHRm.png to dataset.
# On image 1768.
# Appending SGl2ZS1Vbml0Lm90Zg==.png to dataset.
# On image 1769.
# Appending SGlnaE5vb24gSXRhbGljLnR0Zg==.png to dataset.
# On image 1770.
# Appending SGlnaEZpdmUudHRm.png to dataset.
# On image 1771.
# Appending SGlnaGxhbmRlclN0ZC1Cb29rLm90Zg==.png to dataset.
# On image 1772.
# Appending SGlnaGxhbmRlclN0ZC1NZWRpdW1JdGFsaWMub3Rm.png to dataset.
# On image 1773.
# Appending SGlnaGxpZ2h0TFQub3Rm.png to dataset.
# On image 1774.
# Appending SGlnaHN0YWtlcyBSZWd1bGFyLnR0Zg==.png to dataset.
# On image 1775.
# Appending SGlwSG9wRGVtaS50dGY=.png to dataset.
# On image 1776.
# Appending SGlzdG9yeSBSZXBlYXRpbmcgVmVydGljYWwudHRm.png to dataset.
# On image 1777.
# Appending SGVhcnR3b29kIERpc3BsYXkgU1NpLnR0Zg==.png to dataset.
# On image 1778.
# Appending SGVhcnRXaGl0ZSBCZWNrZXIudHRm.png to dataset.
# On image 1779.
# Appending SGVhdGhlciBTY3JpcHQgVHdvLnR0Zg==.png to dataset.
# On image 1780.
# Appending SGVhZGVyMTc2Ny50dGY=.png to dataset.
# On image 1781.
# Appending SGVhZGxpbmUgQ29uZGVuc2VkIE5vcm1hbC50dGY=.png to dataset.
# On image 1782.
# Appending SGVhZGxpbmUgV2lkZSBCb2xkSXRhbGljLnR0Zg==.png to dataset.
# On image 1783.
# Appending SGVhZGxpbmUgV2lkZSBJdGFsaWMudHRm.png to dataset.
# On image 1784.
# Appending SGVhZGxpbmUgVGhpbiBJdGFsaWMudHRm.png to dataset.
# On image 1785.
# Appending SGVhZGxpbmVNVFN0ZC1Cb2xkLm90Zg==.png to dataset.
# On image 1786.
# Appending SGVpZGVsYmVyZy50dGY=.png to dataset.
# On image 1787.
# Appending SGVsaW5kYVJvb2tTdGQub3Rm.png to dataset.
# On image 1788.
# Appending SGVsbG8gQnJhZHkncyBEYWQhLnR0Zg==.png to dataset.
# On image 1789.
# Appending SGVsbGFzQ291ciBCb2xkLnR0Zg==.png to dataset.
# On image 1790.
# Appending SGVsbGVuaWMgTm9ybWFsLnR0Zg==.png to dataset.
# On image 1791.
# Appending SGVsdmV0aWNhLU5hcnJvdy1Cb2xkLm90Zg==.png to dataset.
# On image 1792.
# Appending SGVsdmV0aWNhLUJsYWNrT2JsaXF1ZS5vdGY=.png to dataset.
# On image 1793.
# Appending SGVsdmV0aWNhLUNvbmRlbnNlZC1MaWdodE9ibC5vdGY=.png to dataset.
# On image 1794.
# Appending SGVsdmV0aWNhLUNvbmRlbnNlZC1PYmxpcXVlLm90Zg==.png to dataset.
# On image 1795.
# Appending SGVsdmV0aWNhLUNvbmRlbnNlZC1UaGluLnR0Zg==.png to dataset.
# On image 1796.
# Appending SGVsdmV0aWNhQ3lyLUJvbGQub3Rm.png to dataset.
# On image 1797.
# Appending SGVsdmV0aWNhQ3lyLVVwcmlnaHQub3Rm.png to dataset.
# On image 1798.
# Appending SGVsdmV0aWNhQlEtQmxhY2tJdGFsaWMub3Rm.png to dataset.
# On image 1799.
# Appending SGVsdmV0aWNhQlEtSXRhbGljLm90Zg==.png to dataset.
# On image 1800.
# Appending SGVsdmV0aWNhSW5zZXJhdEJRLVJlZ3VsYXIub3Rm.png to dataset.
# On image 1801.
# Appending SGVsdmV0aWNhTmV1ZS1UaGluLm90Zg==.png to dataset.
# On image 1802.
# Appending SGVsdmV0aWNhTmV1ZS1UaGluQ29uZC5vdGY=.png to dataset.
# On image 1803.
# Appending SGVsdmV0aWNhTmV1ZS1VbHRyYUxpZ0V4dC5vdGY=.png to dataset.
# On image 1804.
# Appending SGVsdmV0aWNhTmV1ZUxULUJvbGRFeHRPYmwub3Rm.png to dataset.
# On image 1805.
# Appending SGVsdmV0aWNhTmV1ZUxULUNvbmRlbnNlZC5vdGY=.png to dataset.
# On image 1806.
# Appending SGVsdmV0aWNhTmV1ZUxULUxpZ2h0RXh0T2JsLm90Zg==.png to dataset.
# On image 1807.
# Appending SGVsdmV0aWNhTmV1ZUxULVRoaW5FeHQub3Rm.png to dataset.
# On image 1808.
# Appending SGVsdmV0aWNhTmV1ZUxULVRoaW5FeHRPYmwub3Rm.png to dataset.
# On image 1809.
# Appending SGVsdmV0aWNhTmV1ZUxULVVsdHJhTGlnQ29uZE9ibC5vdGY=.png to dataset.
# On image 1810.
# Appending SGVsdmV0aWNhTmV1ZUxUU3RkLUJkSXQub3Rm.png to dataset.
# On image 1811.
# Appending SGVsdmV0aWNhUm91bmRlZExULUJvbGRDb25kT2JsLm90Zg==.png to dataset.
# On image 1812.
# Appending SGVsZW5hLUJvbGQudHRm.png to dataset.
# On image 1813.
# Appending SGVybWFubiBJdGFsaWMudHRm.png to dataset.
# On image 1814.
# Appending SGVyciBWb24gTXVlbGxlcmhvZmYudHRm.png to dataset.
# On image 1815.
# Appending SGVyYWxkR290aGljLU1lZGl1bS5vdGY=.png to dataset.
# On image 1816.
# Appending SHlwZXJzcGVlZC50dGY=.png to dataset.
# On image 1817.
# Appending SHV0Y2hpbnNvbi5vdGY=.png to dataset.
# On image 1818.
# Appending SHViYnViIFNTaSBCb2xkLnR0Zg==.png to dataset.
# On image 1819.
# Appending SHVtbnN0Nzc3IEJsa0NuIEJUIEJsYWNrLnR0Zg==.png to dataset.
# On image 1820.
# Appending SHVtbnN0Nzc3IFhCbGtDbiBCVCBFeHRyYSBCbGFjay50dGY=.png to dataset.
# On image 1821.
# Appending SHVtYnVja2VyIE5hc3R5LnR0Zg==.png to dataset.
# On image 1822.
# Appending SHVtYW5hIEV4LnR0Zg==.png to dataset.
# On image 1823.
# Appending SHVtYW5hIFNjcmlwdCBJVEMgVFQgQm9sZC50dGY=.png to dataset.
# On image 1824.
# Appending SHVtYW5hU2Fuc0lUQ1N0ZC1NZWRpdW0ub3Rm.png to dataset.
# On image 1825.
# Appending SHVtYW5hU2NyaXB0SVRDLU1lZGl1bS5vdGY=.png to dataset.
# On image 1826.
# Appending SHVtYW5pc3Q3NzdCVC1FeHRyYUJsYWNrQi5vdGY=.png to dataset.
# On image 1827.
# Appending SHVtYW5pc3Q3NzdCVC1Sb21hbkIub3Rm.png to dataset.
# On image 1828.
# Appending SHVtYW5pc3QgNTIxIEJvbGQgQ29uZGVuc2VkIEJULnR0Zg==.png to dataset.
# On image 1829.
# Appending SHVtYW5pc3QgNTMxIEJsYWNrIEJULnR0Zg==.png to dataset.
# On image 1830.
# Appending SHVtYW5pc3QgOTcwIEJvbGQucGZi.png to dataset.
# On image 1831.
# Appending SHVtYW5pc3QgU2xhYnNlcmlmIDcxMi5wZmI=.png to dataset.
# On image 1832.
# Appending SHVtYW5zdDUzMSBCVCBCb2xkLnR0Zg==.png to dataset.
# On image 1833.
# Appending SHZTdHJpcGUtRXh0cmFCb2xkLnR0Zg==.png to dataset.
# On image 1834.
# Appending SSBqdXN0IGNhbGwudHRm.png to dataset.
# On image 1835.
# Appending STJ0cmlndW5NYXhpbXVtIEUudHRm.png to dataset.
# On image 1836.
# Appending SVNPQ1BFVVIgSXRhbGljLnR0Zg==.png to dataset.
# On image 1837.
# Appending SVRDIE5vdmFyZXNlIEJvbGQgSXRhbGljLnBmYg==.png to dataset.
# On image 1838.
# Appending SVRDIEdhcmFtb25kIEJvb2sgQ29uZGVuc2VkLnBmYg==.png to dataset.
# On image 1839.
# Appending SVRDIEdvdWR5IFNhbnMgQm9sZC5wZmI=.png to dataset.
# On image 1840.
# Appending SVRDIEdvdWR5IFNhbnMgTGlnaHQucGZi.png to dataset.
# On image 1841.
# Appending SVRDIEdvdWR5IFNhbnMgTWVkaXVtLnBmYg==.png to dataset.
# On image 1842.
# Appending SVRDIEF2YW50IEdhcmRlIEdvdGhpYyBFeHRyYSBMaWdodCBPYmxpcXVlLnBmYg==.png to dataset.
# On image 1843.
# Appending SVRDIEF2YW50IEdhcmRlIERlbWkgT2JsaXF1ZSBTV0EudHRm.png to dataset.
# On image 1844.
# Appending SVRDIEFtZXJpY2FuIFR5cGV3cml0ZXIgQm9sZCBBbHRlcm5hdGUucGZi.png to dataset.
# On image 1845.
# Appending SVRDIEFtZXJpY2FuIFR5cGV3cml0ZXIgQm9sZCBDb25kZW5zZWQucGZi.png to dataset.
# On image 1846.
# Appending SVRDIEJlbmd1aWF0IEJvbGQgSXRhbGljLnBmYg==.png to dataset.
# On image 1847.
# Appending SVRDIEN1c2hpbmcgSGVhdnkucGZi.png to dataset.
# On image 1848.
# Appending SVRDIENoYXJ0ZXIgSXRhbGljLnBmYg==.png to dataset.
# On image 1849.
# Appending SVRDIENoZWx0ZW5oYW0gQm9vay5wZmI=.png to dataset.
# On image 1850.
# Appending SVRDIEZyYW5rbGluIEdvdGhpYyBEZW1pLnBmYg==.png to dataset.
# On image 1851.
# Appending SVRDIFRpZmZhbnkgTWVkaXVtLnBmYg==.png to dataset.
# On image 1852.
# Appending SVRDIFRpZXBvbG8gQm9vay5wZmI=.png to dataset.
# On image 1853.
# Appending SVRDIFRpZXBvbG8gQmxhY2sgSXRhbGljLnBmYg==.png to dataset.
# On image 1854.
# Appending SVRDIFVzaGVyd29vZCBCbGFjayBJdGFsaWMucGZi.png to dataset.
# On image 1855.
# Appending SVRDIFVzaGVyd29vZCBNZWRpdW0ucGZi.png to dataset.
# On image 1856.
# Appending SVRDLUJlcmtlbGV5LU9sZC1TdHlsZS1CbGFjay5vdGY=.png to dataset.
# On image 1857.
# Appending SVRDQXZhbnRHYXJkZVN0ZC1Cb2xkQ24ub3Rm.png to dataset.
# On image 1858.
# Appending SVRDQXZhbnRHYXJkZVN0ZC1YTHRDbk9ibC5vdGY=.png to dataset.
# On image 1859.
# Appending SVRDR2FyYW1vbmRTdGQtQmQub3Rm.png to dataset.
# On image 1860.
# Appending SVRDR2FyYW1vbmRTdGQtTHRJdGEub3Rm.png to dataset.
# On image 1861.
# Appending SVRDRnJhbmtsaW5Hb3RoaWNTdGQtQm9va0l0Lm90Zg==.png to dataset.
# On image 1862.
# Appending SVRDS2FiZWxTdGQtTWVkaXVtLm90Zg==.png to dataset.
# On image 1863.
# Appending SWFkZWxvbi1Cb2xkLm90Zg==.png to dataset.
# On image 1864.
# Appending SWFkZWxvbi1EZW1pQm9sZC5vdGY=.png to dataset.
# On image 1865.
# Appending SWJhbGxhbnRpbmVzLUJvbGQub3Rm.png to dataset.
# On image 1866.
# Appending SWNlY3ViZS50dGY=.png to dataset.
# On image 1867.
# Appending SWNoYW50aWxseS1MaWdodC5vdGY=.png to dataset.
# On image 1868.
# Appending SWNsZXJmYWNlLVhsaWdodC5vdGY=.png to dataset.
# On image 1869.
# Appending SWNvbG5vdmEtTWVkaXVtLm90Zg==.png to dataset.
# On image 1870.
# Appending SWNvbmUgTFQgRXh0cmEgQmxhY2sgT3NGLnR0Zg==.png to dataset.
# On image 1871.
# Appending SWNvbmUgTFQgTGlnaHQgSXRhbGljIE9zRi50dGY=.png to dataset.
# On image 1872.
# Appending SWNvbmUgTFQgUmVndWxhciBJdGFsaWMgT3NGLnR0Zg==.png to dataset.
#
#  (1873, 28, 28) Dataset complete
#  Mean: -0.14152060449123383
#  Standard Deviation: 0.44269031286239624

# %% [markdown]
# Pickle stuff!

# %%
def maybe_pickle(data_folders, min_num_images_per_class, force=False):
  dataset_names = []
  for folder in data_folders:
    set_filename = folder + '.pickle'
    dataset_names.append(set_filename)
    if os.path.exists(set_filename) and not force:
      # You may override by setting force=True.
      print('%s already present - Skipping pickling.' % set_filename)
    else:
      print('Pickling %s.' % set_filename)
      dataset = load_letter(folder, min_num_images_per_class)
      try:
        with open(set_filename, 'wb') as f:
          pickle.dump(dataset, f, pickle.HIGHEST_PROTOCOL)
      except Exception as e:
        print('Unable to save data to', set_filename, ':', e)
  
  return dataset_names

train_datasets = maybe_pickle(train_folders, 45000)
test_datasets = maybe_pickle(test_folders, 1800)
